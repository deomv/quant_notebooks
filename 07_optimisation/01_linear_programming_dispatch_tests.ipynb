# %% [markdown]
# # linear programming dispatch — exercises
#
# 12 tasks that test what the cheat sheet `01_linear_programming_dispatch.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("07_optimisation/01_linear_programming_dispatch")

import numpy as np
import pandas as pd
from scipy.optimize import linprog

# %% [markdown]
# ## Task 1
#
# Two generators, two hours. Build the cost vector `c` for `linprog` in the stated variable order `names` (nuclear_h0, nuclear_h1, gas_h0, gas_h1) as a NumPy array.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Build `A_eq` (2 rows × 4 columns) so that row h says 'nuclear_h + gas_h = demand_h', using the same variable order.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Build the `bounds` list for `linprog`: each variable between 0 and its generator's capacity, in the order of `names`. Give it as a list of (low, high) tuples.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Solve the dispatch LP with `linprog(method='highs')` and give the optimal `x` as a NumPy array (order of `names`).
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

c = np.array([12, 12, 50, 50], dtype=float)
A_eq = np.array([[1, 0, 1, 0], [0, 1, 0, 1]], dtype=float)
bounds = [(0, 10), (0, 10), (0, 20), (0, 20)]

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Give the optimal total cost (the objective value) of the same LP as a number.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

c = np.array([12, 12, 50, 50], dtype=float)
A_eq = np.array([[1, 0, 1, 0], [0, 1, 0, 1]], dtype=float)
bounds = [(0, 10), (0, 10), (0, 20), (0, 20)]

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Give the dual values (shadow prices) of the two demand constraints as a NumPy array of length 2. They are the marginal cost of one extra MW in each hour.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

c = np.array([12, 12, 50, 50], dtype=float)
A_eq = np.array([[1, 0, 1, 0], [0, 1, 0, 1]], dtype=float)
bounds = [(0, 10), (0, 10), (0, 20), (0, 20)]

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Raise hour-1 demand to 35 MW (total capacity is only 30). Solve and give `res.status` as an integer.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

c = np.array([12, 12, 50, 50], dtype=float)
A_eq = np.array([[1, 0, 1, 0], [0, 1, 0, 1]], dtype=float)
bounds = [(0, 10), (0, 10), (0, 20), (0, 20)]
demand_big = np.array([8, 35])

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Make the infeasible instance feasible by adding one 'unserved energy' slack variable per hour at a penalty of 1000 EUR/MWh (variable order: the 4 generator variables, then unserved_h0, unserved_h1). Solve and give the unserved MWh in hour 1 as a number.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

demand_big = np.array([8, 35])

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Greedy merit order for a single hour with demand 25 MW: sort generators by cost and fill capacity in order. Give the dispatch as a NumPy array in the order [nuclear, gas].
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# `linprog` minimises. To **maximise** profit Σ (price_h − cost_g)·x, what cost vector `c` do you pass? Prices are 40 EUR/MWh in hour 0 and 60 in hour 1. Give `c` as a NumPy array in the order of `names`.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

price = np.array([40, 60])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# After solving the original LP, which generator sets the price (is marginal) in hour 1? Give its name as a string.
#
# Assign the result to `answer`.

# %%
gens = pd.DataFrame({"cost": [12, 50], "cap": [10, 20]}, index=["nuclear", "gas"])   # EUR/MWh, MW
demand = np.array([8, 25])                                                             # MW in hour 0, hour 1
names = ["nuclear_h0", "nuclear_h1", "gas_h0", "gas_h1"]                               # variable order of x

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: load `../data/hourly_power_clean.csv`, take consumption at 2023-01-24 18:00 UTC scaled to 10% (MW), and dispatch it with a greedy merit order on the fleet `gens5` (ignore wind availability, wind capacity is fully available). Give the total cost in EUR as a number.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).set_index("time")
gens5 = pd.DataFrame({"cost": [12, 0, 65, 85, 160],
                      "cap":  [900, 1500, 600, 1400, 500]},
                     index=["nuclear", "wind", "imports", "ccgt", "ocgt"])
demand_h = float(df.loc["2023-01-24 18:00", "consumption_mwh"]) * 0.10

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
