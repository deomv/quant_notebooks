# %% [markdown]
# # curve fitting and calibration — exercises
#
# 12 tasks that test what the cheat sheet `04_curve_fitting_and_calibration.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("07_optimisation/04_curve_fitting_and_calibration")

import numpy as np
import pandas as pd
from scipy import optimize

# %% [markdown]
# ## Task 1
#
# Write the heating-degree model `y = a + b * max(Th - x, 0)` as a function `model(x_, a, b, Th)` and evaluate it at the six temperatures in `x` with a=5, b=2, Th=15. (Check: at x=5 the value is 5 + 2·10 = 25.)
#
# Assign the result to `answer`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Compute the residual vector `model(x) - y` at the starting point p0 = (a=0, b=1, Th=10).
#
# Assign the result to `answer`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
p0 = [0.0, 1.0, 10.0]

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Compute the sum of squared errors (SSE) at the same starting point p0.
#
# Assign the result to `answer`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
p0 = [0.0, 1.0, 10.0]

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Fit the model to `x`, `y` with `optimize.curve_fit` starting from p0. Assign the fitted parameters `popt` (they should recover a=5, b=2, Th=15).
#
# Assign the result to `answer`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
p0 = [0.0, 1.0, 10.0]

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Now fit the noisy data `y_noisy` (same p0) and assign the parameter standard errors, i.e. the square roots of the diagonal of `pcov`.
#
# Assign the result to `answer`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
p0 = [0.0, 1.0, 10.0]
noise = np.array([0.3, -0.2, 0.1, 0.4, -0.3, 0.2])
y_noisy = y + noise

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Redo the noisy fit with `optimize.least_squares` (write a residual function of theta) with bounds a ∈ (−∞, ∞), b ∈ [0, 10], Th ∈ [16, 30], starting from [0, 1, 20]. Assign the fitted parameters to `theta` and `res.cost` to `cost`. Which parameter sits on a bound?
#
# Assign the result to `theta`, `cost`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
noise = np.array([0.3, -0.2, 0.1, 0.4, -0.3, 0.2])
y_noisy = y + noise

# your solution here
theta = ____
cost = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# `y_spike` is the clean data with one corrupted point. Fit it twice with `least_squares` from p0: once with the default loss and once with `loss='soft_l1', f_scale=1.0`. Assign the robust fit's parameters to `theta_robust` and the plain fit's to `theta_plain`.
#
# Assign the result to `theta_plain`, `theta_robust`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
p0 = [0.0, 1.0, 10.0]
y_spike = y.copy(); y_spike[3] = 30.0

# your solution here
theta_plain = ____
theta_robust = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Standard errors by hand. From a `least_squares` fit `res` on `y_noisy` (start p0, no bounds): sigma² = SSE / (n − p), cov = sigma² · (JᵀJ)⁻¹ with J = `res.jac`, se = sqrt(diag(cov)). Assign `se`.
#
# Assign the result to `se`.

# %%
x = np.array([5.0, 10.0, 15.0, 20.0, 25.0, 30.0])      # temperature
y = np.array([25.0, 15.0, 5.0, 5.0, 5.0, 5.0])          # demand, generated by a=5, b=2, Th=15

def model(x_, a, b, Th):
    return a + b * np.maximum(Th - x_, 0)
p0 = [0.0, 1.0, 10.0]
noise = np.array([0.3, -0.2, 0.1, 0.4, -0.3, 0.2])
y_noisy = y + noise

def residuals(theta_):
    a, b, Th = theta_
    return model(x, a, b, Th) - y_noisy

res = optimize.least_squares(residuals, x0=p0)

# your solution here
se = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# The supply curve is `price(x) = 20 + 3·x + 0.01·x²` (x = residual load in GW). Use `optimize.brentq` on the bracket [0, 100] to find the residual load at which the price reaches 200. Assign the root.
#
# Assign the result to `answer`.

# %%
def price_of(x_):
    return 20 + 3 * x_ + 0.01 * x_ ** 2

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# `ys = 1 + 2·exp(0.0005·xs)` with xs in the thousands. Fitting `exp_model` directly from p0=[1,1,1] silently fails. Fit on the scaled input `zs = xs / 1000` instead and assign `c` converted back to the original units (should be 0.0005).
#
# Assign the result to `answer`.

# %%
xs = np.array([1000.0, 2000.0, 3000.0, 4000.0, 5000.0])
ys = 1 + 2 * np.exp(0.0005 * xs)

def exp_model(x_, a, b, c):
    return a + b * np.exp(c * x_)

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Maximum likelihood for a normal distribution: minimise the negative log-likelihood of `data` over (mu, log_sigma) with `optimize.minimize` (method 'L-BFGS-B', x0=[0, 0]). Assign the fitted `mu` and `sigma` (= exp(log_sigma)). They should equal the sample mean and the ddof=0 standard deviation.
#
# Assign the result to `mu`, `sigma`.

# %%
data = np.array([2.0, 4.0, 4.0, 5.0, 7.0, 8.0])

# your solution here
mu = ____
sigma = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data. `daily` has the 2023 daily mean temperature `T` and daily mean consumption `C`. Fit `C = a + b·max(Th − T, 0)` with `curve_fit` from p0=[25000, 300, 15] and assign the fitted parameters `popt`.
#
# Assign the result to `popt`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])
d23 = df[df["time"].dt.year == 2023].set_index("time")
daily = d23.resample("D").mean()
T = daily["temp_c"].values
C = daily["consumption_mwh"].values

# your solution here
popt = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
