# %% [markdown]
# # halfhourly settlement and panel data — exercises
#
# 12 tasks that test what the cheat sheet `09_halfhourly_settlement_and_panel_data.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("02_pandas/09_halfhourly_settlement_and_panel_data")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Build the UTC timestamp for each row of `toy`: local midnight of `settlement_date` in Europe/London, converted to UTC, plus (period − 1) × 30 minutes. Assign the resulting datetime Series (tz UTC).
#
# Assign the result to `answer`.

# %%
toy = pd.DataFrame({"settlement_date": ["2023-07-01"] * 4, "settlement_period": [1, 2, 3, 4], "kwh": [0.2, 0.3, 0.1, 0.4]})

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# For each `settlement_date` in `rows`, assign the highest `settlement_period` present (a Series indexed by date). One of the dates is a clock-change day.
#
# Assign the result to `answer`.

# %%
rows = pd.DataFrame({"settlement_date": ["2023-03-25"] * 3 + ["2023-03-26"] * 3, "settlement_period": [46, 47, 48, 44, 45, 46]})

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Add the previous period's kwh **per meter** to `long` as a Series (NaN for each meter's first period). A bare `shift(1)` would leak meter A's last value into meter B.
#
# Assign the result to `answer`.

# %%
long = pd.DataFrame({
    "meter": ["A", "A", "A", "B", "B", "B"],
    "period": [1, 2, 3, 1, 2, 3],
    "kwh": [0.2, 0.3, 0.1, 1.0, 1.2, 0.9],
})

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Reshape `long` to wide: one row per `period`, one column per `meter`, values `kwh`.
#
# Assign the result to `answer`.

# %%
long = pd.DataFrame({
    "meter": ["A", "A", "A", "B", "B", "B"],
    "period": [1, 2, 3, 1, 2, 3],
    "kwh": [0.2, 0.3, 0.1, 1.0, 1.2, 0.9],
})

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Reshape `wide` back to long with columns `period`, `meter`, `kwh`, sorted by meter then period, with a fresh 0..n-1 index.
#
# Assign the result to `answer`.

# %%
wide = pd.DataFrame({"A": [0.2, 0.3, 0.1], "B": [1.0, 1.2, 0.9]}, index=pd.Index([1, 2, 3], name="period"))

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# `hh` has half-hourly kWh per meter with a `time` column. Aggregate to **hourly energy per meter** (a Series with a (meter, time) MultiIndex). Energy is summed, not averaged.
#
# Assign the result to `answer`.

# %%
hh = pd.DataFrame({
    "meter": ["A"] * 4 + ["B"] * 4,
    "time": list(pd.date_range("2023-01-01 00:00", periods=4, freq="30min")) * 2,
    "kwh": [0.1, 0.2, 0.3, 0.4, 1.0, 1.0, 2.0, 2.0],
})

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Coincidence factor of the portfolio: (peak of the summed load across meters) / (sum of each meter's individual peak). Assign a float.
#
# Assign the result to `answer`.

# %%
wide = pd.DataFrame({"A": [1.0, 3.0, 2.0], "B": [2.0, 1.0, 3.0]})

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Find the missing (meter, period) combinations in `gappy` given that every meter should have periods 1..4. Assign a sorted list of (meter, period) tuples.
#
# Assign the result to `answer`.

# %%
gappy = pd.DataFrame({"meter": ["A", "A", "A", "B", "B"], "period": [1, 2, 4, 1, 3], "kwh": [1, 1, 1, 2, 2]})

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Add each row's share of its meter's total kwh as a Series aligned with `long` (kwh / meter total).
#
# Assign the result to `answer`.

# %%
long = pd.DataFrame({
    "meter": ["A", "A", "A", "B", "B", "B"],
    "period": [1, 2, 3, 1, 2, 3],
    "kwh": [0.2, 0.3, 0.1, 1.0, 1.2, 0.9],
})

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Real data: load `../data/meter_halfhourly_2023.csv.gz`. How many rows are exact duplicates of another row? Assign the int.
#
# Assign the result to `answer`.

# %%
panel = pd.read_csv("../data/meter_halfhourly_2023.csv.gz")

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Real data: after dropping exact duplicates, which meter has the **most missing periods**? Expected periods per date = the maximum `settlement_period` seen on that date across all meters. Assign the meter id as a string.
#
# Assign the result to `answer`.

# %%
panel = pd.read_csv("../data/meter_halfhourly_2023.csv.gz").drop_duplicates()

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: peak power in kW of meter M100000 (a half-hourly kWh reading × 2). Assign a float.
#
# Assign the result to `answer`.

# %%
panel = pd.read_csv("../data/meter_halfhourly_2023.csv.gz").drop_duplicates()

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
