# %% [markdown]
# # groupby pivot reshape — exercises
#
# 14 tasks that test what the cheat sheet `04_groupby_pivot_reshape.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12, q13, q14 = load_questions("02_pandas/04_groupby_pivot_reshape")

import numpy as np
import pandas as pd

df = pd.DataFrame({
    "region": ["N", "N", "S", "S", "S", "N"],
    "tariff": ["A", "B", "A", "A", "B", "A"],
    "kwh":    [10.0, 20.0, 30.0, 40.0, 50.0, np.nan],
})

# %% [markdown]
# ## Task 1
#
# Total `kwh` per `region` as a Series indexed by region.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Per region, assign the number of **rows** to `n_rows` and the number of **non-missing kwh values** to `n_valid` (both Series indexed by region).
#
# Assign the result to `n_rows`, `n_valid`.

# %%
# your solution here
n_rows = ____
n_valid = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Group by `region` and `tariff` and produce a DataFrame with two columns: `total` (sum of kwh) and `avg` (mean of kwh), using named aggregation.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Assign a Series, aligned with `df`, giving each row's `kwh` as a share of its region's total.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Keep only the rows belonging to (region, tariff) groups that have **at least 2 rows**. Assign the DataFrame.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# `ts` has a `time` column. Assign the mean of `value` by **hour of day** as a Series indexed by hour.
#
# Assign the result to `answer`.

# %%
ts = pd.DataFrame({"time": pd.to_datetime(["2023-01-01 06:00", "2023-01-01 18:00", "2023-01-02 06:00", "2023-01-02 18:00"]), "value": [10, 30, 20, 50]})

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Build a pivot table of the **sum** of `kwh` with `region` as rows and `tariff` as columns, including the `All` margins.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# `wide` has one column per tariff. Melt it into long format with columns `region`, `tariff`, `kwh`.
#
# Assign the result to `answer`.

# %%
wide = pd.DataFrame({"region": ["N", "S"], "A": [10.0, 70.0], "B": [20.0, 50.0]})

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# `g` is a Series with a two-level index (region, tariff). Unstack the `tariff` level into columns. Assign the DataFrame.
#
# Assign the result to `answer`.

# %%
g = df.groupby(["region", "tariff"])["kwh"].sum()

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Assign a crosstab counting rows of `df` by `region` (rows) and `tariff` (columns).
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Assign the running total of `kwh` **within each region**, in the original row order (a Series aligned with `df`).
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Assign the **first** row of each region as a DataFrame indexed by region (columns tariff, kwh).
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ## Task 13
#
# `p` is a long frame of readings per meter, already sorted by meter then day. Assign the rolling mean over 2 days **within each meter** as a Series aligned with `p` (same index as `p`).
#
# Assign the result to `answer`.

# %%
p = pd.DataFrame({"meter": ["A", "A", "A", "B", "B", "B"], "day": [1, 2, 3, 1, 2, 3], "kwh": [1.0, 2.0, 3.0, 10.0, 20.0, 30.0]})

# your solution here
answer = ____

q13.check()

# %%
# q13.hint()
# q13.solution()

# %% [markdown]
# ## Task 14
#
# Real data: from `../data/meter_readings_daily.csv`, assign the 3 meters with the highest **mean** daily kWh as a Series (meter_id → mean kwh), largest first.
#
# Assign the result to `answer`.

# %%
readings = pd.read_csv("../data/meter_readings_daily.csv")

# your solution here
answer = ____

q14.check()

# %%
# q14.hint()
# q14.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
