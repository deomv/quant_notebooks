# %% [markdown]
# # merge join concat — exercises
#
# 13 tasks that test what the cheat sheet `05_merge_join_concat.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12, q13 = load_questions("02_pandas/05_merge_join_concat")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Merge `customers` and `readings` on `meter_id`, keeping only meters present in **both** tables.
#
# Assign the result to `answer`.

# %%
customers = pd.DataFrame({"meter_id": ["M1", "M2", "M3"], "region": ["N", "S", "N"]})
readings = pd.DataFrame({"meter_id": ["M1", "M3", "M4"], "kwh": [10, 30, 40]})

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Merge the same two tables so that **every customer** is kept, with NaN kwh where there is no reading.
#
# Assign the result to `answer`.

# %%
customers = pd.DataFrame({"meter_id": ["M1", "M2", "M3"], "region": ["N", "S", "N"]})
readings = pd.DataFrame({"meter_id": ["M1", "M3", "M4"], "kwh": [10, 30, 40]})

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Find the meter ids that appear in `readings` but **not** in `customers`. Give them as a sorted list of strings.
#
# Assign the result to `answer`.

# %%
customers = pd.DataFrame({"meter_id": ["M1", "M2", "M3"], "region": ["N", "S", "N"]})
readings = pd.DataFrame({"meter_id": ["M1", "M3", "M4"], "kwh": [10, 30, 40]})

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# `tariffs` has meter M1 twice. Left-merge `readings` with `tariffs` on `meter_id` and assign the **number of rows** of the result (an int). Notice it is more than the 3 rows you started with.
#
# Assign the result to `answer`.

# %%
readings = pd.DataFrame({"meter_id": ["M1", "M3", "M4"], "kwh": [10, 30, 40]})
tariffs = pd.DataFrame({"meter_id": ["M1", "M1", "M3"], "tariff": ["A", "B", "A"]})

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Does `readings.merge(tariffs, on='meter_id', validate='one_to_one')` raise an error? Run it inside try/except and assign `True` if it raises, `False` otherwise.
#
# Assign the result to `answer`.

# %%
readings = pd.DataFrame({"meter_id": ["M1", "M3", "M4"], "kwh": [10, 30, 40]})
tariffs = pd.DataFrame({"meter_id": ["M1", "M1", "M3"], "tariff": ["A", "B", "A"]})

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# `sites` calls the key `site_id` while `readings` calls it `meter_id`. Inner-merge them so the result has the columns meter_id, kwh, site_id, name.
#
# Assign the result to `answer`.

# %%
readings = pd.DataFrame({"meter_id": ["M1", "M3", "M4"], "kwh": [10, 30, 40]})
sites = pd.DataFrame({"site_id": ["M1", "M4"], "name": ["Depot", "Shop"]})

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# `load` and `price` are both indexed by hour. Attach `price` to `load` **by index**, keeping every row of `load`.
#
# Assign the result to `answer`.

# %%
load = pd.DataFrame({"mw": [10, 20, 30]}, index=[0, 1, 2])
price = pd.DataFrame({"eur": [50, 70]}, index=[1, 2])

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Merge `est` and `act` on **both** `meter_id` and `date` (inner).
#
# Assign the result to `answer`.

# %%
est = pd.DataFrame({"meter_id": ["M1", "M1", "M2"], "date": ["d1", "d2", "d1"], "kwh_est": [9, 11, 20]})
act = pd.DataFrame({"meter_id": ["M1", "M2", "M2"], "date": ["d1", "d1", "d2"], "kwh_act": [10, 19, 21]})

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Both tables have a column `kwh`. Inner-merge on `meter_id` so the result has columns `kwh_est` and `kwh_act` (in that order after meter_id).
#
# Assign the result to `answer`.

# %%
est = pd.DataFrame({"meter_id": ["M1", "M2"], "kwh": [9, 20]})
act = pd.DataFrame({"meter_id": ["M1", "M2"], "kwh": [10, 19]})

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Stack `jan` on top of `feb` into one frame with a fresh 0..n-1 index.
#
# Assign the result to `answer`.

# %%
jan = pd.DataFrame({"day": [1, 2], "kwh": [10, 12]})
feb = pd.DataFrame({"day": [1, 2], "kwh": [9, 8]})

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# For every row of `actuals`, attach the **latest forecast published at or before** that time, but only if it was published within the last 2 hours (otherwise NaN).
#
# Assign the result to `answer`.

# %%
actuals = pd.DataFrame({"time": pd.to_datetime(["2023-01-01 01:00", "2023-01-01 02:00", "2023-01-01 05:00"]), "load": [10, 20, 50]})
forecasts = pd.DataFrame({"time": pd.to_datetime(["2023-01-01 00:30", "2023-01-01 01:30"]), "fc": [11, 21]})

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# `primary` has gaps. Fill them from `backup`, keeping the primary value wherever it exists.
#
# Assign the result to `answer`.

# %%
primary = pd.Series([1.0, np.nan, 3.0, np.nan], index=["a", "b", "c", "d"])
backup = pd.Series([9.0, 2.0, 9.0, 4.0], index=["a", "b", "c", "d"])

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ## Task 13
#
# Real data: load `../data/meters.csv` and `../data/meter_readings_daily.csv`. How many reading rows belong to a meter that is **not** in the meters table? Assign the count as an int.
#
# Assign the result to `answer`.

# %%
meters = pd.read_csv("../data/meters.csv")
readings = pd.read_csv("../data/meter_readings_daily.csv")

# your solution here
answer = ____

q13.check()

# %%
# q13.hint()
# q13.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
