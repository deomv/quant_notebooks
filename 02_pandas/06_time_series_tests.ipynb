# %% [markdown]
# # time series — exercises
#
# 13 tasks that test what the cheat sheet `06_time_series.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12, q13 = load_questions("02_pandas/06_time_series")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# `df` has a `time` column stored as text, in random order. Return a frame indexed by a real DatetimeIndex, sorted by time.
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({"time": ["2023-01-01 02:00", "2023-01-01 00:00", "2023-01-01 01:00"], "mw": [12, 10, 11]})

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# `s72` is 72 hourly values over three days. Select every row of the second day (2023-01-02) using a partial date string.
#
# Assign the result to `answer`.

# %%
s72 = pd.Series(range(72), index=pd.date_range("2023-01-01", periods=72, freq="h"))

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# From the `time` column of `df`, build a DataFrame with two integer columns `hour` and `dow` (Monday = 0).
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({"time": pd.to_datetime(["2023-01-01 07:00", "2023-01-02 18:00", "2023-01-07 23:00"])})

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# It is 12:00 local time in London on 2023-07-01 (British Summer Time). What is the hour in UTC? Assign the integer.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# `s` is hourly but 02:00 is missing. Reindex it to the complete hourly grid from its first to its last timestamp (assign to `on_grid`) and count the missing hours (assign the int to `n_missing`).
#
# Assign the result to `on_grid`, `n_missing`.

# %%
idx = pd.to_datetime(["2023-01-01 00:00", "2023-01-01 01:00", "2023-01-01 03:00", "2023-01-01 04:00", "2023-01-01 05:00"])
s = pd.Series([10, 11, 13, 14, 15], index=idx)   # 02:00 is missing

# your solution here
on_grid = ____
n_missing = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Aggregate `s` into 2-hour totals with the default settings (each bar labelled by its **start**).
#
# Assign the result to `answer`.

# %%
idx = pd.to_datetime(["2023-01-01 00:00", "2023-01-01 01:00", "2023-01-01 03:00", "2023-01-01 04:00", "2023-01-01 05:00"])
s = pd.Series([10, 11, 13, 14, 15], index=idx)   # 02:00 is missing

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Aggregate `s` into 2-hour totals where each bar is labelled by its **end** timestamp and includes that end timestamp (`closed='right'`).
#
# Assign the result to `answer`.

# %%
idx = pd.to_datetime(["2023-01-01 00:00", "2023-01-01 01:00", "2023-01-01 03:00", "2023-01-01 04:00", "2023-01-01 05:00"])
s = pd.Series([10, 11, 13, 14, 15], index=idx)   # 02:00 is missing

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Move every value of `s` one hour **later by timestamp** (not by row), so that the value for 01:00 lands on 02:00 even though 02:00 was not in the index.
#
# Assign the result to `answer`.

# %%
idx = pd.to_datetime(["2023-01-01 00:00", "2023-01-01 01:00", "2023-01-01 03:00", "2023-01-01 04:00", "2023-01-01 05:00"])
s = pd.Series([10, 11, 13, 14, 15], index=idx)   # 02:00 is missing

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Compute the trailing mean of `s` over a **3-hour time window** (so the gap at 02:00 shortens the window), not over 3 rows.
#
# Assign the result to `answer`.

# %%
idx = pd.to_datetime(["2023-01-01 00:00", "2023-01-01 01:00", "2023-01-01 03:00", "2023-01-01 04:00", "2023-01-01 05:00"])
s = pd.Series([10, 11, 13, 14, 15], index=idx)   # 02:00 is missing

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Build a leak-free feature: for each hour, the mean of the **previous three** values of `y` (not including the current one).
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50, 60], index=pd.date_range("2023-01-01", periods=6, freq="h"))

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Select the rows of `s72` whose time of day is between 17:00 and 19:00 inclusive.
#
# Assign the result to `answer`.

# %%
s72 = pd.Series(range(72), index=pd.date_range("2023-01-01", periods=72, freq="h"))

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: load `../data/hourly_power_clean.csv` and compute the average `consumption_mwh` for each hour of the day (a Series indexed 0..23).
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ## Task 13
#
# Real data: load `../data/hourly_power_raw.csv` (unsorted, with duplicates). Parse `time` as UTC, drop duplicate timestamps, and count how many hours are missing between the first and last timestamp. Assign the int.
#
# Assign the result to `answer`.

# %%
raw = pd.read_csv("../data/hourly_power_raw.csv")

# your solution here
answer = ____

q13.check()

# %%
# q13.hint()
# q13.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
