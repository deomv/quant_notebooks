# %% [markdown]
# # load inspect — exercises
#
# 12 tasks that test what the cheat sheet `01_load_inspect.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("02_pandas/01_load_inspect")

import io
import numpy as np
import pandas as pd

CSV = '''time,price,region,flag
2023-01-01 00:00,70.16,GB,1
2023-01-01 01:00,missing,GB,1
2023-01-01 02:00,23.19,GB,0
2023-01-01 02:00,23.19,GB,0
2023-01-01 04:00,115.79,GB,1
'''

# %% [markdown]
# ## Task 1
#
# Read the CSV text in `CSV` (wrap it with `io.StringIO`) so that the `time` column is parsed as a datetime. Assign the DataFrame.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = pd.read_csv(io.StringIO(CSV), parse_dates=["time"])

q1.check()
# Out:
# ✅ Correct.
# True

# %%
# q1.hint()
#q1.solution()
answer
# Out:
#                  time    price region  flag
# 0 2023-01-01 00:00:00    70.16     GB     1
# 1 2023-01-01 01:00:00  missing     GB     1
# 2 2023-01-01 02:00:00    23.19     GB     0
# 3 2023-01-01 02:00:00    23.19     GB     0
# 4 2023-01-01 04:00:00   115.79     GB     1

# %% [markdown]
# ## Task 2
#
# Read `CSV` again, but keep only the columns `time` and `price` (in that order) and make `price` numeric by telling `read_csv` that the string `missing` means NaN.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = pd.read_csv(io.StringIO(CSV),usecols=["time","price"], na_values=["missing"], parse_dates=["time"])

q2.check()
# Out:
# ✅ Correct. expected columns ['time', 'price'] with a float price column containing one NaN
# True

# %%
# q2.hint()
q2.solution()
# Out:
# Solution for task 2:
#
#     answer = pd.read_csv(io.StringIO(CSV), usecols=["time", "price"], na_values=["missing"])

# %% [markdown]
# ## Task 3
#
# `df` was read with no options. Assign the dtype of each column (the `dtypes` Series).
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV))

# your solution here
answer = df.dtypes

q3.check()
# Out:
# ✅ Correct. expected the df.dtypes Series (time and price are object, region object, flag int64)
# True

# %%
answer
# Out:
# time      object
# price     object
# region    object
# flag       int64
# dtype: object

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# How many rows of `df` are exact duplicates of an earlier row? Assign the integer.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV))

# your solution here
answer = df.duplicated().sum()


q4.check()
# Out:
# ✅ Correct.
# True

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
# q4.hint()
q4.solution()
# Out:
# Solution for task 4:
#
#     answer = int(df.duplicated().sum())

# %% [markdown]
# ## Task 5
#
# Assign the **share** (fraction between 0 and 1) of missing values per column of `df`, as a Series indexed by column name.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV), na_values=["missing"])

# your solution here
answer = df.isna().sum()

q5.check()
# Out:
# ❌ Not yet. Series are different
# False

# %%
# q5.hint()
q5.solution()
#answer
# Out:
# Solution for task 5:
#
#     answer = df.isna().mean()

# %% [markdown]
# ## Task 6
#
# Assign the number of distinct values per column of `df` as a Series.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV), na_values=["missing"])

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Assign a **sorted list** of the names of the columns of `df` that are constant (hold a single distinct value).
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV), na_values=["missing"])

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Parse `time`, sort it, and count how often each gap between consecutive timestamps occurs. Assign the `value_counts()` Series (index = Timedelta, values = counts).
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV))

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Assign a **sorted list** of the column names of `df` whose dtype is object (text).
#
# Assign the result to `answer`.

# %%
df = pd.read_csv(io.StringIO(CSV))

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Real data: read `../data/hourly_power_raw.csv` with no options and assign its shape as a tuple `(rows, columns)`.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Real data: in `raw`, how many rows have the literal text `missing` in `price_eur_mwh`? Assign the integer.
#
# Assign the result to `answer`.

# %%
raw = pd.read_csv("../data/hourly_power_raw.csv")

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: parse `raw['time']` as UTC timestamps and assign the earliest to `t_min` and the latest to `t_max`.
#
# Assign the result to `t_min`, `t_max`.

# %%
raw = pd.read_csv("../data/hourly_power_raw.csv")

# your solution here
t_min = ____
t_max = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
