# %% [markdown]
# # pitfalls and debugging — exercises
#
# 12 tasks that test what the cheat sheet `07_pitfalls_and_debugging.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("02_pandas/07_pitfalls_and_debugging")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# The rows of `df` are not in time order. Add a column `lag` holding the value of `v` from the **previous hour** (in time order), but keep the rows of `df` in their current order. A colleague wrote `df['lag'] = df.sort_index()['v'].shift(1).values` — that is wrong. Do it correctly.
#
# Assign the result to `answer`.

# %%
idx = pd.to_datetime(["2023-01-01 02:00", "2023-01-01 00:00", "2023-01-01 01:00"])
df = pd.DataFrame({"v": [30, 10, 20]}, index=idx)

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# `s` has unsorted timestamps. Return the hour-over-hour difference, with the result sorted by time.
#
# Assign the result to `answer`.

# %%
s = pd.Series([30, 10, 20], index=pd.to_datetime(["2023-01-01 02:00", "2023-01-01 00:00", "2023-01-01 01:00"]))

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# `s` has 01:00 twice. Keep the **last** value for each timestamp, then compute the previous-row lag with shift(1).
#
# Assign the result to `answer`.

# %%
s = pd.Series([10, 11, 99, 13], index=pd.to_datetime(["2023-01-01 00:00", "2023-01-01 01:00", "2023-01-01 01:00", "2023-01-01 02:00"]))

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# The `price` column was read as text and contains the word 'missing'. Assign the mean of the numeric prices (a float), ignoring the bad value.
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({"price": ["70.0", "80.0", "missing", "90.0"]})

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Daily totals of `s`: the second day has no data at all, so its total must be NaN, not 0.
#
# Assign the result to `answer`.

# %%
s = pd.Series([1.0, 2.0, np.nan, np.nan], index=pd.to_datetime(["2023-01-01 00:00", "2023-01-01 12:00", "2023-01-02 00:00", "2023-01-02 12:00"]))

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Set `x` to 0 wherever `flag` is True. `df[df.flag]['x'] = 0` does nothing — write the version that works, returning a **new** frame (do not mutate `df`).
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({"x": [5, 6, 7], "flag": [True, False, True]})

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# `right` has duplicated keys, so a plain merge multiplies the rows of `left`. Deduplicate `right` on `key` (keep the first), then left-merge so the result has exactly as many rows as `left`.
#
# Assign the result to `answer`.

# %%
left = pd.DataFrame({"key": ["a", "b", "c"], "v": [1, 2, 3]})
right = pd.DataFrame({"key": ["a", "a", "b"], "w": [10, 11, 20]})

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# `df.time` is tz-naive but the values are UTC; `cutoff` is tz-aware. Count the rows with time >= cutoff (an int). Comparing them directly raises, so localise first.
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({"time": pd.to_datetime(["2023-01-01 00:00", "2023-01-01 06:00", "2023-01-01 12:00"])})
cutoff = pd.Timestamp("2023-01-01 06:00", tz="UTC")

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Fill the gaps in `s` using **only past** information (a leak-free fill).
#
# Assign the result to `answer`.

# %%
s = pd.Series([10.0, np.nan, np.nan, 40.0, np.nan], index=pd.date_range("2023-01-01", periods=5, freq="h"))

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# The dates in `raw` are written day-first ('03/04/2023' is 3 April). Parse them into a datetime Series correctly.
#
# Assign the result to `answer`.

# %%
raw = pd.Series(["03/04/2023", "15/04/2023", "01/05/2023"])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# `a` and `b` should be equal but differ by floating-point noise. Count how many pairs are equal within 1e-9 (an int). `(a == b).sum()` gives the wrong answer.
#
# Assign the result to `answer`.

# %%
a = pd.Series([0.1 + 0.2, 1.0, 2.5])
b = pd.Series([0.3, 1.0, 2.5000001])

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Reindexing `s` to labels 0..3 introduces a NaN and silently turns the integers into floats. Return the reindexed Series with the nullable integer dtype `Int64` so the existing values stay integers.
#
# Assign the result to `answer`.

# %%
s = pd.Series([1, 2, 3])

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
