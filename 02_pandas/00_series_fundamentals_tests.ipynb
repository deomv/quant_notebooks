# %% [markdown]
# # series fundamentals — exercises
#
# 12 tasks that test what the cheat sheet `00_series_fundamentals.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("02_pandas/00_series_fundamentals")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Create a Series with values 5, 10, 15 and index labels 'a', 'b', 'c', named 'load'.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = pd.Series([5,10,15], index=["a", "b", "c"], name='load')

q1.check()
# Out:
# ✅ Correct.
# True

# %%
# q1.hint()
q1.solution()
# Out:
# Solution for task 1:
#
#     answer = pd.Series([5, 10, 15], index=["a", "b", "c"], name="load")

# %% [markdown]
# ## Task 2
#
# From `s`, select the values for labels 'c' and 'a', in that order.
#
# Assign the result to `answer`.

# %%
s = pd.Series([100, 200, 300, 400], index=["a", "b", "c", "d"])

# your solution here
answer = s.loc[["c","a"]]

q2.check()
# Out:
# ✅ Correct.
# True

# %%
answer
# Out:
# c    300
# a    100
# dtype: int64

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# From `s`, take the last two values **by position**.
#
# Assign the result to `answer`.

# %%
s = pd.Series([100, 200, 300, 400], index=["a", "b", "c", "d"])

# your solution here
answer = s.iloc[-2:]
q3.check()
# Out:
# ✅ Correct.
# True

# %%
# q3.hint()
q3.solution()
# Out:
# Solution for task 3:
#
#     answer = s.iloc[-2:]

# %% [markdown]
# ## Task 4
#
# Keep only the values of `s` that are strictly between 150 and 350.
#
# Assign the result to `answer`.

# %%
s = pd.Series([100, 200, 300, 400], index=["a", "b", "c", "d"])

# your solution here
answer = s[ (s < 350) & ( s >150) ]

q4.check()
# Out:
# ✅ Correct.
# True

# %%
answer
# Out:
# b    200
# c    300
# dtype: int64

# %% [markdown]
# ## Task 5
#
# Reindex `s` to the labels ['d', 'e', 'a'] so that the label that does not exist becomes 0 instead of NaN.
#
# Assign the result to `answer`.

# %%
s = pd.Series([100, 200, 300, 400], index=["a", "b", "c", "d"])

# your solution here
answer = s.reindex(["d","e","a"], fill_value=0)

q5.check()
# Out:
# ✅ Correct.
# True

# %%
answer
# Out:
# d    400
# e      0
# a    100
# dtype: int64

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Add `a` and `b` so that labels present in only one of them are treated as 0 (no NaN in the result).
#
# Assign the result to `answer`.

# %%
a = pd.Series([1, 2, 3], index=["x", "y", "z"])
b = pd.Series([10, 20, 30], index=["y", "z", "w"])

# your solution here
answer = a.add(b, fill_value=0)

q6.check()
# Out:
# ✅ Correct.
# True

# %%
answer
# Out:
# w    30.0
# x     1.0
# y    12.0
# z    23.0
# dtype: float64

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# `temp` uses -999 as a 'missing' marker. Replace every value below -100 with NaN (keep the other values).
#
# Assign the result to `answer`.

# %%
temp = pd.Series([5.0, -999.0, 7.0, -999.0, 9.0])

# your solution here
answer = temp.mask(temp<-100)

q7.check()
# Out:
# ✅ Correct.
# True

# %%
# q7.hint()
q7.solution()
# Out:
# Solution for task 7:
#
#     answer = temp.mask(temp <= -100)

# %% [markdown]
# ## Task 8
#
# Build a DataFrame with three columns from `y`: `y` itself, `lag1` (the previous value) and `roll2` (the mean of the two **previous** values, not including the current one).
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50], index=pd.date_range('2023-01-01', periods=5, freq='h'))

# your solution here
answer = pd.DataFrame({"y":y, "lag1":y.shift(1), "roll2":y.shift(1).rolling(2).mean()})

q8.check()
# Out:
# ✅ Correct.
# True

# %%
# q8.hint()
# q8.solution()
answer
# Out:
#                       y  lag1  roll2
# 2023-01-01 00:00:00  10   NaN    NaN
# 2023-01-01 01:00:00  20  10.0    NaN
# 2023-01-01 02:00:00  30  20.0   15.0
# 2023-01-01 03:00:00  40  30.0   25.0
# 2023-01-01 04:00:00  50  40.0   35.0

# %% [markdown]
# ## Task 9
#
# `region` should be mapped to a zone with the dictionary `zones`. Regions that are **not** in the dictionary must keep their original name.
#
# Assign the result to `answer`.

# %%
region = pd.Series(["London", "Wales", "North", "Scotland"])
zones = {"London": "South", "Wales": "West"}

# your solution here
answer = region.replace(zones)

q9.check()
# Out:
# ✅ Correct.
# True

# %%
# q9.hint()
#q9.solution()
answer
# Out:
# 0       South
# 1        West
# 2       North
# 3    Scotland
# dtype: object

# %% [markdown]
# ## Task 10
#
# `txt` holds prices as text, with one bad value. Convert it to numbers so the bad value becomes NaN, and assign the number of NaN to `n_bad` and the numeric Series to `answer`.
#
# Assign the result to `answer`, `n_bad`.

# %%
txt = pd.Series(["70.16", "23.19", "missing", "115.79"])

# your solution here
answer = pd.to_numeric(txt, errors='coerce')
n_bad = pd.isna(answer).sum()


q10.check()
# Out:
# ✅ Correct.
# True

# %%
# q10.hint()
#q10.solution()
answer
# Out:
# 0     70.16
# 1     23.19
# 2       NaN
# 3    115.79
# dtype: float64

# %% [markdown]
# ## Task 11
#
# `d` has a duplicated label 'a'. Keep only the **last** occurrence of each label so the index becomes unique.
#
# Assign the result to `answer`.

# %%
d = pd.Series([1, 2, 3, 4], index=["a", "a", "b", "c"])

# your solution here
#answer =

d[~d.index.duplicated(keep="last")]
#q11.check()
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
# q11.hint()
q11.solution()
# Out:
# Solution for task 11:
#
#     answer = d[~d.index.duplicated(keep="last")]

# %% [markdown]
# ## Task 12
#
# On the real data: load `../data/hourly_power_clean.csv`, make a Series of `consumption_mwh` indexed by `time`, and assign the **timestamp** (index label) of the maximum consumption.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])

cons = df.set_index("time")["consumption_mwh"]
answer = cons.idxmax()

q12.check()
# Out:
# ✅ Correct.
# True

# %%
answer
# Out:
# Timestamp('2022-02-07 18:00:00+0000', tz='UTC')

# %%
# q12.hint()
# q12.solution()
idx = df["consumption_mwh"].idxmax()
t = df.iloc[idx]["time"]
v = df.iloc[idx]["consumption_mwh"]

pd.Series(  v ,index=[t])
# Out:
# 2022-02-07 18:00:00+00:00    40824.9
# dtype: float64

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
