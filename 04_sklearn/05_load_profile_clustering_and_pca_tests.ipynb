# %% [markdown]
# # load profile clustering and pca — exercises
#
# 12 tasks that test what the cheat sheet `05_load_profile_clustering_and_pca.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("04_sklearn/05_load_profile_clustering_and_pca")

import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Task 1
#
# Cluster the six 2-D points `P` into 2 groups with `KMeans(n_clusters=2, random_state=0, n_init=10)`. Assign the label array to `answer` (label numbering does not matter, the grouping does).
#
# Assign the result to `answer`.

# %%
P = np.array([[0, 0], [0, 1], [1, 0], [10, 10], [10, 11], [11, 10]], dtype=float)

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Fit the same KMeans on `P` and assign the cluster centres, **sorted by their first coordinate**, as a 2×2 array to `answer`.
#
# Assign the result to `answer`.

# %%
P = np.array([[0, 0], [0, 1], [1, 0], [10, 10], [10, 11], [11, 10]], dtype=float)

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Recompute the centre of the cluster containing point `[0, 0]` by hand: the mean of the points that share its label. Assign the 1-D array to `answer`.
#
# Assign the result to `answer`.

# %%
P = np.array([[0, 0], [0, 1], [1, 0], [10, 10], [10, 11], [11, 10]], dtype=float)
labels = KMeans(n_clusters=2, random_state=0, n_init=10).fit_predict(P)

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Compute the inertia by hand: sum over points of squared distance to their own cluster centre. Assign the float to `answer` (it should equal `km.inertia_`).
#
# Assign the result to `answer`.

# %%
P = np.array([[0, 0], [0, 1], [1, 0], [10, 10], [10, 11], [11, 10]], dtype=float)
km = KMeans(n_clusters=2, random_state=0, n_init=10).fit(P)

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# `D` holds five 4-period daily profiles; two are big versions of the others. Normalise each row to sum to 1 (shape, not size). Assign the normalised array to `answer`.
#
# Assign the result to `answer`.

# %%
D = np.array([[1, 1, 4, 2], [10, 10, 40, 20], [3, 1, 1, 3], [30, 10, 10, 30], [2, 2, 2, 2]], dtype=float)

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Cluster the row-normalised `D` into 2 groups with `KMeans(n_clusters=2, random_state=0, n_init=10)`. Assign the labels to `answer`. The two 'big' days should now join their small twins.
#
# Assign the result to `answer`.

# %%
D = np.array([[1, 1, 4, 2], [10, 10, 40, 20], [3, 1, 1, 3], [30, 10, 10, 30], [2, 2, 2, 2]], dtype=float)
Dn = D / D.sum(axis=1, keepdims=True)

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# For k in [2, 3, 4], fit `KMeans(n_clusters=k, random_state=0, n_init=10)` on `Q` and collect the inertia. Assign a Series indexed by k with the inertias to `answer`.
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(0)
Q = np.vstack([rng.normal(0, 0.3, (10, 2)), rng.normal(5, 0.3, (10, 2)), rng.normal([0, 5], 0.3, (10, 2))])

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Compute the silhouette score of the k=3 clustering of `Q` (same KMeans settings). Assign the float to `answer`.
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(0)
Q = np.vstack([rng.normal(0, 0.3, (10, 2)), rng.normal(5, 0.3, (10, 2)), rng.normal([0, 5], 0.3, (10, 2))])

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Fit `PCA(n_components=2)` on the 4×2 matrix `M` and assign `explained_variance_ratio_` to `answer`.
#
# Assign the result to `answer`.

# %%
M = np.array([[1, 2], [2, 4], [3, 6.5], [4, 8]], dtype=float)

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Project `M` onto its first principal component and reconstruct it back with `PCA(n_components=1)`. Assign the reconstruction error (sum of squared differences between `M` and the reconstruction, float) to `answer`.
#
# Assign the result to `answer`.

# %%
M = np.array([[1, 2], [2, 4], [3, 6.5], [4, 8]], dtype=float)

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# `GroupKFold(n_splits=3)` on 6 rows with `groups`. Assign a list of the **test group names** per fold (each fold as a sorted list of the distinct group values in its test set) to `answer`.
#
# Assign the result to `answer`.

# %%
X = np.arange(6).reshape(-1, 1)
groups = np.array(["A", "A", "B", "B", "C", "C"])

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data. `X_shape` holds row-normalised meter-day profiles (48 columns). Standardise the columns with `StandardScaler`, fit `PCA(n_components=3)` and assign the **cumulative** explained variance ratio of the 3 components (float, rounded to 3 decimals) to `answer`.
#
# Assign the result to `answer`.

# %%
raw = pd.read_csv("../data/meter_halfhourly_2023.csv.gz").drop_duplicates()
raw["date"] = pd.to_datetime(raw["settlement_date"])
raw = raw[raw["meter_id"] != "M100007"]
per_day = raw.groupby(["meter_id", "date"])["kwh"].agg(n="size", nunique="nunique")
keep = per_day[(per_day["n"] == 48) & (per_day["nunique"] > 1)].index
raw = raw.set_index(["meter_id", "date"]).loc[keep].reset_index()
X_raw = raw.pivot_table(index=["meter_id", "date"], columns="settlement_period", values="kwh")
gross = X_raw.abs().sum(axis=1)
X_shape = X_raw[gross > 1].div(gross[gross > 1], axis=0)

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
