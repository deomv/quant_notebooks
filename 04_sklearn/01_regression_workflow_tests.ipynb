# %% [markdown]
# # regression workflow — exercises
#
# 11 tasks that test what the cheat sheet `01_regression_workflow.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11 = load_questions("04_sklearn/01_regression_workflow")

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ## Task 1
#
# Fit a `LinearRegression` on `X` and `y` (y is exactly 2·x1 + 3). Assign the fitted coefficient array to `coef` and the intercept (a float) to `intercept`.
#
# Assign the result to `coef`, `intercept`.

# %%
X = pd.DataFrame({"x1": [1, 2, 3, 4, 5, 6]})
y = pd.Series([5, 7, 9, 11, 13, 15])

# your solution here
coef = ____
intercept = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Using `y_true` and `pred`, compute the RMSE **by hand** (no sklearn): mean of squared errors, then square root. Assign the float to `answer`.
#
# Assign the result to `answer`.

# %%
y_true = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Compute R² of `pred` against `y_true` with sklearn. Be careful with the argument order (true values first). Assign the float to `answer`.
#
# Assign the result to `answer`.

# %%
y_true = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Fit `LinearRegression` on the two-feature `X` and `y` (y = 3·x1 − 2·x2 + 1) and build a Series of coefficients indexed by feature name, sorted from smallest to largest.
#
# Assign the result to `answer`.

# %%
X = pd.DataFrame({"x1": [1, 2, 3, 4, 5, 6], "x2": [2, 1, 4, 3, 6, 5]})
y = pd.Series(3 * X["x1"] - 2 * X["x2"] + 1)

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# `df` has 8 hourly rows. Do a **chronological** split with the first 6 rows as train and the last 2 as test. Assign the list of test-set timestamps (as strings 'YYYY-MM-DD HH:MM') to `answer`.
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({"time": pd.date_range("2023-01-01", periods=8, freq="h"), "y": [1, 2, 3, 4, 5, 6, 7, 8]})

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Fit OLS and `Ridge(alpha=10)` on the same `X`, `y`. Assign the OLS coefficient array to `ols_coef` and the Ridge coefficient array to `ridge_coef`. (Ridge should be visibly smaller in absolute value.)
#
# Assign the result to `ols_coef`, `ridge_coef`.

# %%
X = pd.DataFrame({"x1": [1, 2, 3, 4, 5, 6], "x2": [2, 1, 4, 3, 6, 5]})
y = pd.Series(3 * X["x1"] - 2 * X["x2"] + 1)

# your solution here
ols_coef = ____
ridge_coef = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# One-hot encode the `hour` column of `X` with `pd.get_dummies`, dropping the first category, and keep the numeric columns as integers 0/1. Assign the resulting DataFrame's column names as a list to `answer`.
#
# Assign the result to `answer`.

# %%
X = pd.DataFrame({"temp": [5, 6, 7, 8], "hour": [0, 1, 2, 3]})

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Compute the naive 'same value one step earlier' baseline for the last 4 rows of `y` (the test part): prediction for row t is y at row t−1. Assign the RMSE of that baseline on the 4 test rows to `answer` (float).
#
# Assign the result to `answer`.

# %%
y = pd.Series([10.0, 12.0, 11.0, 15.0, 14.0, 16.0, 18.0, 17.0])

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# `out` has true values, predictions and an `hour` column. Compute the **mean error** (true − pred) per hour as a Series indexed by hour.
#
# Assign the result to `answer`.

# %%
out = pd.DataFrame({"hour": [0, 1, 0, 1, 0, 1], "y": [10, 20, 12, 22, 11, 21], "pred": [11, 18, 11, 19, 12, 18]})

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Real data. `df`, `features`, `target` and the chronological `split` are given. Fit `LinearRegression` on the first `split` rows and assign the test-set RMSE (float, rounded to 1 decimal) to `answer`.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).sort_values("time").reset_index(drop=True)
df["hour"] = df["time"].dt.hour
df["weekend"] = (df["time"].dt.dayofweek >= 5).astype(int)
df["hdd"] = np.clip(15 - df["temp_c"], 0, None)
features = ["temp_c", "hdd", "wind_ms", "solar_wm2", "hour", "weekend"]
target = "consumption_mwh"
split = int(len(df) * 0.8)

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Real data, continued. Compute the RMSE of the naive **same hour yesterday** baseline (`shift(24)`) on the same test rows. Assign a boolean `answer`: does the model from the previous task beat this baseline (model RMSE < naive RMSE)?
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).sort_values("time").reset_index(drop=True)
df["hour"] = df["time"].dt.hour
df["weekend"] = (df["time"].dt.dayofweek >= 5).astype(int)
df["hdd"] = np.clip(15 - df["temp_c"], 0, None)
features = ["temp_c", "hdd", "wind_ms", "solar_wm2", "hour", "weekend"]
target = "consumption_mwh"
split = int(len(df) * 0.8)
train, test = df.iloc[:split], df.iloc[split:]
model_rmse = float(np.sqrt(mean_squared_error(test[target], LinearRegression().fit(train[features], train[target]).predict(test[features]))))

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
