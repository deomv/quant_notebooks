# %% [markdown]
# # model diagnostics and interpretation — exercises
#
# 12 tasks that test what the cheat sheet `04_model_diagnostics_and_interpretation.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("04_sklearn/04_model_diagnostics_and_interpretation")

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.inspection import permutation_importance

# %% [markdown]
# ## Task 1
#
# Build an error table from `y` and `pred`: a DataFrame with columns `y`, `pred`, `error` (= y − pred). Then assign the **mean error** (bias, float) to `bias` and the table to `answer`.
#
# Assign the result to `answer`, `bias`.

# %%
y = pd.Series([10.0, 12.0, 11.0, 15.0, 14.0, 16.0])
pred = pd.Series([11.0, 11.0, 12.0, 14.0, 15.0, 15.0])

# your solution here
answer = ____
bias = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# From `err` (errors over time), compute the **rolling RMSE with a window of 3**: square, rolling mean, square root. Assign the Series to `answer`.
#
# Assign the result to `answer`.

# %%
err = pd.Series([1.0, -1.0, 2.0, -2.0, 3.0, -3.0])

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Fit `LinearRegression` on the first 6 rows of `X`, `y` and compute RMSE on train (rows 0–5) and on test (rows 6–9). Assign both floats to `rmse_train` and `rmse_test`.
#
# Assign the result to `rmse_train`, `rmse_test`.

# %%
rng = np.random.default_rng(0)
X = pd.DataFrame({"x": np.arange(10.0)})
y = 2 * X["x"] + rng.normal(0, 1, 10)

# your solution here
rmse_train = ____
rmse_test = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Coefficient stability: fit `LinearRegression` on `X`, `y` separately for `period == 'A'` and `period == 'B'`. Assign a DataFrame with index `['x1', 'x2']` and columns `A`, `B` holding the coefficients to `answer`.
#
# Assign the result to `answer`.

# %%
X = pd.DataFrame({"x1": [1, 2, 3, 4, 1, 2, 3, 4], "x2": [1, 1, 2, 2, 2, 2, 1, 1]})
y = pd.Series([3, 5, 8, 10, 4, 6, 7, 9])
period = pd.Series(["A"] * 4 + ["B"] * 4)

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Compute the VIF of column `x2` in `X` by hand: regress `x2` on the other columns, get R², VIF = 1 / (1 − R²). Assign the float to `answer`.
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(0)
x1 = rng.normal(size=50)
X = pd.DataFrame({"x1": x1, "x2": x1 + rng.normal(0, 0.1, 50), "x3": rng.normal(size=50)})

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Fit OLS and `Ridge(alpha=1.0)` on the collinear `X` (x2 ≈ x1). Assign the OLS coefficient array to `ols` and the Ridge one to `ridge`. Ridge should spread the weight across x1 and x2.
#
# Assign the result to `ols`, `ridge`.

# %%
rng = np.random.default_rng(0)
x1 = rng.normal(size=50)
X = pd.DataFrame({"x1": x1, "x2": x1 + rng.normal(0, 0.1, 50)})
y = 2 * x1 + rng.normal(0, 0.5, 50)

# your solution here
ols = ____
ridge = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Permutation importance by hand for `x1`: fit `LinearRegression` on `X`, `y`, record R² on `X`; then shuffle column `x1` with `rng.permutation` (rng seeded 0, as given) and recompute R². Assign the **drop** in R² (baseline − shuffled, float) to `answer`.
#
# Assign the result to `answer`.

# %%
rng_data = np.random.default_rng(1)
X = pd.DataFrame({"x1": rng_data.normal(size=40), "x2": rng_data.normal(size=40)})
y = 3 * X["x1"] + 0.1 * X["x2"]
rng = np.random.default_rng(0)

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Use sklearn's `permutation_importance` on the fitted model with `n_repeats=5, random_state=0` and assign the `importances_mean` array to `answer`.
#
# Assign the result to `answer`.

# %%
rng_data = np.random.default_rng(1)
X = pd.DataFrame({"x1": rng_data.normal(size=40), "x2": rng_data.normal(size=40)})
y = 3 * X["x1"] + 0.1 * X["x2"]
m = LinearRegression().fit(X, y)

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Partial dependence by hand: for `x1` in [−1, 0, 1], set every row's `x1` to that value, keep `x2` at its **median**, and predict with `m`. Assign the array of three mean predictions to `answer`.
#
# Assign the result to `answer`.

# %%
rng_data = np.random.default_rng(1)
X = pd.DataFrame({"x1": rng_data.normal(size=40), "x2": rng_data.normal(size=40)})
y = 3 * X["x1"] + 0.1 * X["x2"] + 1
m = LinearRegression().fit(X, y)

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Residual autocorrelation: assign the lag-1 autocorrelation of `resid` (float) to `answer`.
#
# Assign the result to `answer`.

# %%
resid = pd.Series([1.0, 0.8, 0.5, -0.2, -0.6, -0.4, 0.1, 0.5])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# The leaked-feature detector. `X` contains a column `roll2` computed as `y.rolling(2).mean()` **without** shifting (it contains y itself) and `lag1`. Fit `LinearRegression` on the rows without NaN and assign the coefficient on `roll2` (float) and the in-sample R² (float) to `coef_roll2` and `r2`.
#
# Assign the result to `coef_roll2`, `r2`.

# %%
y = pd.Series([10.0, 12.0, 11.0, 15.0, 14.0, 16.0, 18.0, 17.0])
X = pd.DataFrame({"roll2": y.rolling(2).mean(), "lag1": y.shift(1)})
mask = X.notna().all(axis=1)

# your solution here
coef_roll2 = ____
r2 = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data. Fit `Ridge(alpha=1.0)` on the given lag model with a chronological split, then compute the **mean error by hour of day** on the test set. Assign the hour (int) with the largest **absolute** mean error to `answer`.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).sort_values("time").reset_index(drop=True)
y = df["consumption_mwh"]
X = pd.DataFrame({"lag1": y.shift(1), "lag24": y.shift(24), "temp": df["temp_c"]}).dropna()
y = y.loc[X.index]
hour = df.loc[X.index, "time"].dt.hour
split = int(len(X) * 0.8)

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
