# %% [markdown]
# # hypothesis tests power and pitfalls — exercises
#
# 12 tasks that test what the cheat sheet `04_hypothesis_tests_power_and_pitfalls.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("03_scipy/04_hypothesis_tests_power_and_pitfalls")

import numpy as np
import pandas as pd
from scipy import stats
rng = np.random.default_rng(0)

# %% [markdown]
# ## Task 1
#
# A test gave t = 2.3 with 20 degrees of freedom. Compute the **two-sided** p-value with `stats.t.sf` (the survival function, i.e. the upper tail). Assign it to `answer`.
#
# Assign the result to `answer`.

# %%
t_stat = 2.3
df = 20

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Same t and df, but the **one-sided** alternative 'greater than'. Assign the p-value to `answer`.
#
# Assign the result to `answer`.

# %%
t_stat = 2.3
df = 20

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Permutation test, one step: `values` holds 6 observations, the first 3 from group A and the last 3 from group B. The observed statistic is mean(B) − mean(A). Apply the permutation `perm` to `values` (i.e. `values[perm]`), split it 3/3 again, and assign the **permuted** statistic mean(B') − mean(A') to `answer`.
#
# Assign the result to `answer`.

# %%
values = np.array([10.0, 12.0, 11.0, 15.0, 14.0, 16.0])
perm = np.array([3, 0, 5, 1, 4, 2])

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Full permutation test: with `rng` (seeded 5), repeat 2000 times: `perm = rng.permutation(6)`, compute the permuted statistic as in the previous task, and count how often its **absolute value** is at least the absolute observed statistic (mean(B) − mean(A) on the original order). Assign the p-value = count / 2000 to `answer`.
#
# Assign the result to `answer`.

# %%
values = np.array([10.0, 12.0, 11.0, 15.0, 14.0, 16.0])
rng = np.random.default_rng(5)

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Type I error by simulation: with `rng` (seeded 11), draw `sims = rng.normal(0, 1, size=(4000, 2, 15))` — 4000 experiments, each with two groups of 15 from the **same** distribution. Run `stats.ttest_ind` on each pair (equal_var=True) and assign the **fraction of p-values below 0.05** to `answer`. It should be close to 0.05.
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(11)

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Power by the normal approximation: for a two-sample test with n = 30 per group, sd = 1, true difference d = 0.5 and alpha = 0.05 (two-sided), the power is approximately `1 − Φ(z_crit − d / sqrt(2/n))` with z_crit = 1.96 and Φ the standard normal cdf. Assign it to `answer`.
#
# Assign the result to `answer`.

# %%
n = 30
d = 0.5
sd = 1.0

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Paired vs unpaired: `err_a` and `err_b` are the daily errors of two forecast models on the **same** 6 days. Run the paired t-test (`stats.ttest_rel`) and the unpaired one (`stats.ttest_ind`, equal_var=False) and assign the two p-values to `p_paired` and `p_unpaired`.
#
# Assign the result to `p_paired`, `p_unpaired`.

# %%
err_a = np.array([5.0, 7.0, 6.0, 9.0, 4.0, 8.0])
err_b = np.array([4.5, 6.4, 5.6, 8.3, 3.7, 7.5])

# your solution here
p_paired = ____
p_unpaired = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Bonferroni: for the 6 p-values in `pvals` at family-wise alpha 0.05, compute the corrected threshold and the boolean array of which tests are significant. Assign the threshold to `threshold` and the boolean array to `significant`.
#
# Assign the result to `threshold`, `significant`.

# %%
pvals = np.array([0.002, 0.009, 0.011, 0.030, 0.049, 0.300])

# your solution here
threshold = ____
significant = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Benjamini–Hochberg on the same `pvals`: adjust them with `stats.false_discovery_control` and assign the **number** of adjusted p-values below 0.05 to `answer` (an integer).
#
# Assign the result to `answer`.

# %%
pvals = np.array([0.002, 0.009, 0.011, 0.030, 0.049, 0.300])

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Effect size: compute Cohen's d for `b` versus `a`, defined as (mean(b) − mean(a)) / pooled_sd, where pooled_sd = sqrt((var_a + var_b) / 2) with variances using ddof=1. Assign it to `answer`.
#
# Assign the result to `answer`.

# %%
a = np.array([10.0, 12.0, 11.0, 13.0, 9.0])
b = np.array([14.0, 15.0, 13.0, 16.0, 12.0])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Newey–West with one lag: for the residuals `e` (mean zero), the iid variance of the mean is γ0/n and the lag-1-adjusted variance is (γ0 + 2·w·γ1)/n with Bartlett weight w = 1/2, where γ0 = mean(e²) and γ1 = mean(e[1:]·e[:-1]). Assign `var_iid` and `var_nw`.
#
# Assign the result to `var_iid`, `var_nw`.

# %%
e = np.array([1.0, 0.8, 0.5, -0.2, -0.6, -1.0, -0.5, 0.0])

# your solution here
var_iid = ____
var_nw = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Optional stopping: `pvals_over_time` holds the p-value of a running test after each batch of data (batch 1, 2, ..., 8). An analyst stops and declares success at the **first** batch where p < 0.05. Assign the 1-based batch number at which they stop to `answer` (an integer), or 0 if they never would.
#
# Assign the result to `answer`.

# %%
pvals_over_time = np.array([0.40, 0.21, 0.09, 0.04, 0.12, 0.20, 0.03, 0.06])

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
