# %% [markdown]
# # optimize interpolate signal — exercises
#
# 12 tasks that test what the cheat sheet `02_optimize_interpolate_signal.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("03_scipy/02_optimize_interpolate_signal")

import numpy as np
import pandas as pd
from scipy import optimize, interpolate, signal
rng = np.random.default_rng(0)

# %% [markdown]
# ## Task 1
#
# Minimise f(x) = (x − 3)² + 2 with `optimize.minimize` starting from x0 = 0. Assign the minimiser (a float) to `x_star` and the minimum value to `f_star`.
#
# Assign the result to `x_star`, `f_star`.

# %%
def f(x):
    return (x[0] - 3) ** 2 + 2

# your solution here
x_star = ____
f_star = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Minimise the two-variable function g(x, y) = (x − 1)² + (y + 2)² from the start point (0, 0). Assign the minimiser as a NumPy array of length 2 to `answer`.
#
# Assign the result to `answer`.

# %%
def g(p):
    return (p[0] - 1) ** 2 + (p[1] + 2) ** 2

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# The points `(x, y)` lie exactly on a straight line. Fit `line(x, a, b) = a*x + b` with `optimize.curve_fit` and assign the fitted parameters array `popt` to `answer`.
#
# Assign the result to `answer`.

# %%
def line(x, a, b):
    return a * x + b

x = np.array([0.0, 1.0, 2.0, 3.0, 4.0])
y = np.array([1.0, 3.0, 5.0, 7.0, 9.0])

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Fit the exponential model `expo(x, a, k) = a * exp(k * x)` to `(x, y)` with `curve_fit`, using starting values p0 = [1, 0.1]. Assign the fitted `a` to `a_hat` and the fitted `k` to `k_hat`.
#
# Assign the result to `a_hat`, `k_hat`.

# %%
def expo(x, a, k):
    return a * np.exp(k * x)

x = np.array([0.0, 1.0, 2.0, 3.0, 4.0])
y = 2.0 * np.exp(0.5 * x)

# your solution here
a_hat = ____
k_hat = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Find the root of h(x) = x³ − 2x − 5 that lies between 2 and 3 with `optimize.brentq`. Assign it to `answer`.
#
# Assign the result to `answer`.

# %%
def h(x):
    return x**3 - 2 * x - 5

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Find the minimiser of k(x) = x⁴ − 3x² + x on the interval [0, 2] with `optimize.minimize_scalar` using `method='bounded'`. Assign the minimiser to `answer`.
#
# Assign the result to `answer`.

# %%
def k(x):
    return x**4 - 3 * x**2 + x

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Solve this LP with `optimize.linprog` (method 'highs'): minimise 3·x₁ + 2·x₂ subject to x₁ + x₂ ≥ 4, x₁ ≤ 3, x₂ ≤ 3, both non-negative. Remember linprog wants ≤ constraints. Assign the solution array to `x_opt` and the objective value to `obj`.
#
# Assign the result to `x_opt`, `obj`.

# %%
# your solution here
x_opt = ____
obj = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# The LP in the previous task has an equality version: minimise 3·x₁ + 2·x₂ subject to x₁ + x₂ = 4, 0 ≤ x₁ ≤ 3, 0 ≤ x₂ ≤ 3. Solve it and assign the **dual value (marginal) of the equality constraint** to `answer`.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Given the known points `xp`, `fp`, linearly interpolate the values at `x_new = [0.5, 1.5, 2.5]` with `np.interp`. Assign the array to `answer`.
#
# Assign the result to `answer`.

# %%
xp = np.array([0.0, 1.0, 2.0, 3.0])
fp = np.array([0.0, 10.0, 30.0, 60.0])
x_new = np.array([0.5, 1.5, 2.5])

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# `y` has a gap (NaN) at position 2. Fill it by **linear interpolation** between its neighbours using `interpolate.interp1d` on the non-NaN points (or `np.interp`). Assign the fully filled array to `answer`.
#
# Assign the result to `answer`.

# %%
t = np.arange(6.0)
y = np.array([1.0, 2.0, np.nan, 4.0, 5.0, 6.0])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Remove the linear trend from `z` with `signal.detrend` and assign the detrended array to `answer`.
#
# Assign the result to `answer`.

# %%
z = np.array([1.0, 3.0, 5.0, 7.0, 9.0, 11.0]) + np.array([0.5, -0.5, 0.5, -0.5, 0.5, -0.5])

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Smooth `z` with a centred 3-point moving average using pandas (`rolling(3, center=True).mean()`), keeping NaN at the two ends. Assign the resulting Series to `answer`.
#
# Assign the result to `answer`.

# %%
z = pd.Series([1.0, 4.0, 2.0, 8.0, 5.0, 9.0])

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
