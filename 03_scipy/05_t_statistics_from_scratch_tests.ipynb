# %% [markdown]
# # t statistics from scratch — exercises
#
#     14 tasks that test what the cheat sheet `05_t_statistics_from_scratch.ipynb` covers. Try each one
#     **before** looking at the cheat sheet.
#
#     How it works:
#     1. Read the task. Write your code in the cell below it, assigning the result to the
#        variable the task names (usually `answer`).
#     2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
#     3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.
#
# Every task can be done with the formulas from the cheat sheet; use SciPy only to check.
# Two-sided p: `2 * stats.t.sf(abs(t), df)`; one-sided: `stats.t.sf(t, df)`; critical value: `stats.t.ppf(1 - alpha/2, df)`.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12, q13, q14 = load_questions("03_scipy/05_t_statistics_from_scratch")

import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# ## Task 1
#
# One-sample t-test of $H_0: \mu = 0$ on `a`: compute the t-statistic by hand ($\bar a / (s/\sqrt n)$, $s$ with ddof=1). Assign the number.
#
# Assign the result to `answer`.

# %%
a = np.array([1.2, 0.4, 2.1, -0.3, 1.5, 0.9, 1.8, 0.2])

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# For that t-statistic compute the two-sided p-value `p_two` and the one-sided p-value for $H_1: \mu > 0$, `p_one`, using the t distribution with $n-1$ df.
#
# Assign the result to `p_two`, `p_one`.

# %%
a = np.array([1.2, 0.4, 2.1, -0.3, 1.5, 0.9, 1.8, 0.2])

# your solution here
p_two = ____
p_one = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# What is the two-sided 5% critical value of the t distribution with 7 degrees of freedom, and with 1000? Assign `crit7` and `crit1000`.
#
# Assign the result to `crit7`, `crit1000`.

# %%
# your solution here
crit7 = ____
crit1000 = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Build 20,000 draws of $t_5$ from its parts: `Z = rng.normal(0, 1, 20000)` then `V = rng.chisquare(5, 20000)` (exactly these two calls, in this order), and compute $t = Z/\sqrt{V/5}$. Assign the fraction of $|t| > 1.96$ to `frac` and the theoretical value $2\,P(T_5 > 1.96)$ to `theory`.
#
# Assign the result to `frac`, `theory`.

# %%
rng = np.random.default_rng(1)

# your solution here
frac = ____
theory = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Two-sample **pooled** t-test of equal means for `a` vs `b`: compute the pooled variance $s_p^2$, the SE $s_p\sqrt{1/n_a + 1/n_b}$ and the t-statistic. Assign `sp2` and `t_pooled`.
#
# Assign the result to `sp2`, `t_pooled`.

# %%
a = np.array([1.2, 0.4, 2.1, -0.3, 1.5, 0.9, 1.8, 0.2])
b = np.array([0.1, -0.5, 0.8, 0.3, -0.2, 0.6, 0.0, -0.4, 0.5, 0.2])

# your solution here
sp2 = ____
t_pooled = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Now **Welch**: SE $= \sqrt{s_a^2/n_a + s_b^2/n_b}$ and the Welch–Satterthwaite degrees of freedom. Assign `t_welch` and `df_welch`.
#
# Assign the result to `t_welch`, `df_welch`.

# %%
a = np.array([1.2, 0.4, 2.1, -0.3, 1.5, 0.9, 1.8, 0.2])
b = np.array([0.1, -0.5, 0.8, 0.3, -0.2, 0.6, 0.0, -0.4, 0.5, 0.2])

# your solution here
t_welch = ____
df_welch = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Two models' daily absolute errors `e1`, `e2` on the same 8 days. Compute the **paired** t-statistic on the differences `e1 - e2`, and the **unpaired** Welch t-statistic. Assign `t_paired` and `t_unpaired`.
#
# Assign the result to `t_paired`, `t_unpaired`.

# %%
e1 = np.array([3.1, 1.2, 4.5, 2.2, 5.0, 1.8, 3.6, 2.9])
e2 = np.array([2.8, 1.0, 4.1, 2.0, 4.6, 1.7, 3.2, 2.6])

# your solution here
t_paired = ____
t_unpaired = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# For `x`, `y` compute the correlation coefficient and its t-statistic $t = r\sqrt{n-2}/\sqrt{1-r^2}$. Assign `r` and `t_r`.
#
# Assign the result to `r`, `t_r`.

# %%
x = np.array([0.5, 1.5, 2.0, 3.5, 4.0, 5.5, 6.0, 7.5])
y = np.array([1.0, 1.2, 2.8, 2.9, 4.1, 4.0, 5.9, 6.2])

# your solution here
r = ____
t_r = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# A strategy has an annualised Sharpe ratio of 1.2 measured over 4 years. Assign its t-statistic (`SR * sqrt(years)`) to `t_sr`, and the number of years needed for that Sharpe to reach t = 2 to `years_needed`.
#
# Assign the result to `t_sr`, `years_needed`.

# %%
sr, years = 1.2, 4

# your solution here
t_sr = ____
years_needed = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Power by simulation: with `rng`, draw `x = rng.normal(0.2, 1.0, size=(5000, 50))` (exactly once), compute the one-sample t of each row, and assign the fraction that exceeds the one-sided 5% critical value with 49 df to `power`.
#
# Assign the result to `power`.

# %%
rng = np.random.default_rng(2)

# your solution here
power = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# `y` is an AR(1) series with true mean 0. Assign its naive t-statistic to `t_naive` and its effective sample size $n(1-\hat\rho_1)/(1+\hat\rho_1)$ (with the standard lag-1 estimator) to `n_eff`.
#
# Assign the result to `t_naive`, `n_eff`.

# %%
rng = np.random.default_rng(9)
eps = rng.normal(0, 1, 500)
y = np.zeros(500)
for t in range(1, 500):
    y[t] = 0.7 * y[t - 1] + eps[t]

# your solution here
t_naive = ____
n_eff = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: daily mean consumption, weekdays vs weekends, 2023 only. Assign the Welch t-statistic to `t_welch` and the difference of means (weekday minus weekend, MWh/h) to `diff`.
#
# Assign the result to `t_welch`, `diff`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).set_index("time")
day = df.loc["2023"].resample("D").mean()
dow = day.index.dayofweek

# your solution here
t_welch = ____
diff = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ## Task 13
#
# Real data, paired: per-day mean absolute error of the 'same hour yesterday' forecast (`shift(24)`) vs 'same hour last week' (`shift(168)`) for hourly consumption in 2023. Assign the paired t-statistic (lag24 minus lag168) to `t_paired`.
#
# Assign the result to `t_paired`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).set_index("time")
cons = df["consumption_mwh"]

# your solution here
t_paired = ____

q13.check()

# %%
# q13.hint()
# q13.solution()

# %% [markdown]
# ## Task 14
#
# Real data, correlation with the confounder removed: for daily means in 2023, subtract each ISO week's mean from wind and from price, then assign the correlation of the demeaned series to `r_dm` and its t-statistic to `t_dm`.
#
# Assign the result to `r_dm`, `t_dm`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"]).set_index("time")
day = df.loc["2023"].resample("D").mean()
key = [day.index.isocalendar().year, day.index.isocalendar().week]

# your solution here
r_dm = ____
t_dm = ____

q14.check()

# %%
# q14.hint()
# q14.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
