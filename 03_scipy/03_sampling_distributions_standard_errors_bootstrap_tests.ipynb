# %% [markdown]
# # sampling distributions standard errors bootstrap — exercises
#
# 12 tasks that test what the cheat sheet `03_sampling_distributions_standard_errors_bootstrap.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("03_scipy/03_sampling_distributions_standard_errors_bootstrap")

import numpy as np
import pandas as pd
from scipy import stats
rng = np.random.default_rng(0)

# %% [markdown]
# ## Task 1
#
# For the sample `x`, compute the sample mean, the sample standard deviation (ddof=1) and the **standard error of the mean** sd/sqrt(n). Assign them to `mean`, `sd`, `se`.
#
# Assign the result to `mean`, `sd`, `se`.

# %%
x = np.array([12.0, 15.0, 9.0, 14.0, 10.0, 12.0, 11.0, 13.0])

# your solution here
mean = ____
sd = ____
se = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# If the population sd is 20, how many observations `n` do you need for the standard error of the mean to be at most 2? Assign the smallest such integer to `answer`.
#
# Assign the result to `answer`.

# %%
# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Simulate the sampling distribution of the mean: draw a `(2000, 5)` array of normal(loc=50, scale=10) values with `rng.normal(50, 10, size=(2000, 5))`, take the mean of each row, and assign the **standard deviation (ddof=1) of the 2000 row means** to `answer`. It should be close to 10/sqrt(5).
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(42)

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Build a 95% **z**-interval for the mean of `x`: mean ± 1.96 · se (se = sd/sqrt(n), sd with ddof=1). Assign `lower` and `upper`.
#
# Assign the result to `lower`, `upper`.

# %%
x = np.array([12.0, 15.0, 9.0, 14.0, 10.0, 12.0, 11.0, 13.0])

# your solution here
lower = ____
upper = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Same interval but with the **t** critical value for n−1 degrees of freedom instead of 1.96 (use `stats.t.ppf(0.975, df=n-1)`). Assign `lower_t` and `upper_t`. Notice they are wider.
#
# Assign the result to `lower_t`, `upper_t`.

# %%
x = np.array([12.0, 15.0, 9.0, 14.0, 10.0, 12.0, 11.0, 13.0])

# your solution here
lower_t = ____
upper_t = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Check interval coverage by simulation: `sims = rng.normal(0, 1, size=(1000, 10))` (use rng once, this shape). For each row build the z-interval mean ± 1.96·sd/sqrt(10) with ddof=1, and assign the **fraction of rows whose interval contains the true mean 0** to `answer`.
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(7)

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# One bootstrap of the mean: with `rng`, draw resample indices `idx = rng.integers(0, len(x), size=(500, len(x)))`, compute the mean of `x[idx]` along axis 1 for each resample, and assign the **standard deviation (ddof=1) of the 500 bootstrap means** (the bootstrap SE) to `answer`.
#
# Assign the result to `answer`.

# %%
x = np.array([12.0, 15.0, 9.0, 14.0, 10.0, 12.0, 11.0, 13.0])
rng = np.random.default_rng(1)

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Using the same bootstrap draw (`idx = rng.integers(0, len(x), size=(500, len(x)))` with `rng` seeded 1), compute the **percentile 95% bootstrap interval** for the mean: the 2.5th and 97.5th percentiles of the bootstrap means (use `np.percentile`). Assign `lower` and `upper`.
#
# Assign the result to `lower`, `upper`.

# %%
x = np.array([12.0, 15.0, 9.0, 14.0, 10.0, 12.0, 11.0, 13.0])
rng = np.random.default_rng(1)

# your solution here
lower = ____
upper = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Bootstrap a **median**: with `idx = rng.integers(0, len(x), size=(500, len(x)))` (rng seeded 1), take the median of each resample and assign the standard deviation (ddof=1) of the 500 bootstrap medians to `answer`.
#
# Assign the result to `answer`.

# %%
x = np.array([12.0, 15.0, 9.0, 14.0, 10.0, 12.0, 11.0, 13.0])
rng = np.random.default_rng(1)

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# A series has lag-1 autocorrelation ρ = 0.9 and n = 17,520 hourly observations. Compute the **effective sample size** n·(1−ρ)/(1+ρ) and assign it to `answer` (a float).
#
# Assign the result to `answer`.

# %%
n = 17520
rho = 0.9

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# The iid standard error of the mean of `y` is sd/sqrt(n). Compute the **autocorrelation-adjusted** SE sd/sqrt(n_eff) where n_eff = n·(1−ρ)/(1+ρ) and ρ is the lag-1 autocorrelation of `y` estimated with `pd.Series(y).autocorr(1)`. Assign `se_iid` and `se_adj` (sd with ddof=1).
#
# Assign the result to `se_iid`, `se_adj`.

# %%
y = np.array([1.0, 1.5, 2.0, 2.4, 2.6, 2.5, 2.2, 1.8, 1.4, 1.1])

# your solution here
se_iid = ____
se_adj = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Block bootstrap indices: split the 12 positions 0..11 into 4 consecutive blocks of length 3, then with `rng` (seeded 3) draw 4 block numbers with `rng.integers(0, 4, size=4)` and build the resampled index array by concatenating the chosen blocks in the drawn order. Assign the length-12 integer array to `answer`.
#
# Assign the result to `answer`.

# %%
n = 12
block_len = 3
rng = np.random.default_rng(3)

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
