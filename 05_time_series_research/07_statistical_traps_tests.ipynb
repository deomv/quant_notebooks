# %% [markdown]
# # statistical traps — exercises
#
# 12 tasks that test what the cheat sheet `07_statistical_traps.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("05_time_series_research/07_statistical_traps")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Simpson's paradox. Compute `overall` = cost per kWh by region (total cost / total kWh, a Series indexed by region) and `reverses` = True if region A is cheaper than B **within both customer types** yet dearer than B **overall**.
#
# Assign the result to `overall`, `reverses`.

# %%
toy = pd.DataFrame({
    "region":        ["A", "A", "B", "B"],
    "customer_type": ["residential", "sme", "residential", "sme"],
    "kwh":           [9000, 1000, 1000, 9000],
    "cost":          [2700, 200, 320, 1890],
})

# your solution here
overall = ____
reverses = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Regression to the mean. `top2_change` = mean change (day2 − day1) for the 2 meters with the highest day1; `all_change` = mean change for all meters.
#
# Assign the result to `top2_change`, `all_change`.

# %%
toy = pd.DataFrame({"meter": list("abcdef"), "day1": [10, 50, 20, 45, 15, 30], "day2": [12, 30, 22, 28, 14, 29]})

# your solution here
top2_change = ____
all_change = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Survivorship. `growth_all` = mean growth over all five customers; `growth_survivors` = mean growth over customers who did **not** churn.
#
# Assign the result to `growth_all`, `growth_survivors`.

# %%
toy = pd.DataFrame({"growth": [0.02, 0.01, -0.05, 0.03, -0.04], "churned": [False, False, True, False, True]})

# your solution here
growth_all = ____
growth_survivors = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Base rates. A spike detector has sensitivity 0.95 and specificity 0.95; spikes occur in 2% of hours. Compute the precision: P(spike | alarm).
#
# Assign the result to `answer`.

# %%
sensitivity = 0.95
specificity = 0.95
prevalence = 0.02

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Mean of ratios vs ratio of sums. `mean_of_prices` = plain mean of price; `volume_weighted` = total cost / total volume.
#
# Assign the result to `mean_of_prices`, `volume_weighted`.

# %%
toy = pd.DataFrame({"price": [50, 100, 300], "volume_mwh": [10, 10, 1]})

# your solution here
mean_of_prices = ____
volume_weighted = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Averaging percentages. `unweighted` = mean of the three regional solar shares; `weighted` = total meters with solar / total meters.
#
# Assign the result to `unweighted`, `weighted`.

# %%
g = pd.DataFrame({"region": ["A", "B", "C"], "meters": [900, 50, 50], "solar_share": [0.05, 0.40, 0.45]})

# your solution here
unweighted = ____
weighted = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Expected maximum of noise. With `rng = np.random.default_rng(0)`, draw `rng.normal(size=(10000, 5))` (10,000 trials of 5 strategies with zero true skill) and compute the average of the best-of-5 value across trials.
#
# Assign the result to `answer`.

# %%
rng = np.random.default_rng(0)

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Best-of-N selection. Pick the strategy with the best P&L in the first 10 days (`best`, its name) and report that same strategy's P&L in the next 10 days (`next_pnl`).
#
# Assign the result to `best`, `next_pnl`.

# %%
toy = pd.DataFrame({"strategy": ["s1", "s2", "s3", "s4", "s5"], "first10": [2, -4, 8, 0, -2], "next10": [1, 3, -6, 2, 0]}).set_index("strategy")

# your solution here
best = ____
next_pnl = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Multiple comparisons. From the 20 p-values in `pvals`, count how many are below 0.05 (`n_raw`) and how many are below the Bonferroni threshold 0.05 / 20 (`n_bonf`).
#
# Assign the result to `n_raw`, `n_bonf`.

# %%
pvals = np.array([0.30, 0.01, 0.55, 0.03, 0.72, 0.001, 0.41, 0.09, 0.66, 0.21, 0.38, 0.85, 0.12, 0.47, 0.93, 0.06, 0.29, 0.51, 0.77, 0.19])

# your solution here
n_raw = ____
n_bonf = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# The improvement that is one period. `wins_b` = number of months in which model B has lower RMSE than A; `annual_b_better` = True if B's annual RMSE (sqrt of the mean of squared monthly RMSEs) is lower than A's.
#
# Assign the result to `wins_b`, `annual_b_better`.

# %%
rmse_a = pd.Series([100.0] * 12)
rmse_b = pd.Series([103.0] * 11 + [55.0])

# your solution here
wins_b = ____
annual_b_better = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Berkson's paradox. Customers complain if they have a high bill **or** poor service. Compute `corr_all` = correlation between high_bill and poor_service over everyone, and `corr_complainers` = the same correlation among complainers only.
#
# Assign the result to `corr_all`, `corr_complainers`.

# %%
toy = pd.DataFrame({"high_bill": [1, 1, 1, 1, 0, 0, 0, 0], "poor_service": [1, 1, 0, 0, 1, 1, 0, 0]})

# your solution here
corr_all = ____
corr_complainers = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data, 2023 only: `time_weighted` = plain mean of the hourly price; `load_weighted` = sum(price × consumption) / sum(consumption).
#
# Assign the result to `time_weighted`, `load_weighted`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])
h = df[df["time"].dt.year == 2023]

# your solution here
time_weighted = ____
load_weighted = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
