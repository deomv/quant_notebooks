# %% [markdown]
# # evaluation and baselines — exercises
#
# 12 tasks that test what the cheat sheet `02_evaluation_and_baselines.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("05_time_series_research/02_evaluation_and_baselines")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Compute the RMSE of `pred` against `y` by hand (no sklearn): square root of the mean squared error.
#
# Assign the result to `answer`.

# %%
y = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Compute the MAE (mean absolute error) of `pred` against `y`.
#
# Assign the result to `answer`.

# %%
y = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Compute MAPE and sMAPE as **fractions** (not percent). MAPE = mean(|y−pred| / |y|); sMAPE = mean(2·|y−pred| / (|y|+|pred|)). Assign `mape` and `smape`.
#
# Assign the result to `mape`, `smape`.

# %%
y = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
mape = ____
smape = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Compute MASE: the MAE of `pred` divided by the MAE of the in-sample naive one-step forecast, i.e. divided by the mean absolute difference between consecutive values of `y`.
#
# Assign the result to `answer`.

# %%
y = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Compute R² by hand: 1 − SS_res / SS_tot, where SS_res = Σ(y−pred)² and SS_tot = Σ(y−mean(y))².
#
# Assign the result to `answer`.

# %%
y = np.array([10.0, 20.0, 30.0, 40.0])
pred = np.array([12.0, 18.0, 33.0, 37.0])

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# `y` repeats with period 4. Compute the RMSE of the naive forecast 'same value 4 rows earlier' over the rows where that forecast exists.
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 12, 18, 33, 37])

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Walk-forward split of `n` rows: the first train set has `initial` rows, each test block has `step` rows, and the train set grows to include everything before the block. Assign a list of `(train_end, test_end)` tuples (both end positions exclusive), one per test block.
#
# Assign the result to `answer`.

# %%
n = 12
initial = 6
step = 2

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# `ev` has an `hour` column and an `error` column. Assign the mean error per hour (a Series indexed by hour).
#
# Assign the result to `answer`.

# %%
ev = pd.DataFrame({
    "hour":  [0, 0, 0, 18, 18, 18],
    "error": [-2, -4, -3, 5, 6, 7],
})

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Compute the rolling RMSE of `err` with a window of 3 rows: the square root of the rolling mean of squared errors. Keep NaN where the window is incomplete.
#
# Assign the result to `answer`.

# %%
err = pd.Series([1.0, 2.0, 2.0, 10.0, 1.0, 1.0])

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Diebold–Mariano-style test. `err_a` and `err_b` are paired errors of two models. Let d = err_a² − err_b². Assign the t-statistic of the mean of d: mean(d) / (std(d, ddof=1) / √n).
#
# Assign the result to `answer`.

# %%
err_a = np.array([3.0, -2.0, 4.0, -3.0, 2.0])
err_b = np.array([1.0, -1.0, 2.0, -2.0, 1.0])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Empirical 90% prediction interval. From the training residuals `resid`, assign `lower` = 5% quantile and `upper` = 95% quantile (np.quantile with the default interpolation). Then assign `coverage` = the fraction of test rows where `y_test` lies within `[pred_test + lower, pred_test + upper]`.
#
# Assign the result to `lower`, `upper`, `coverage`.

# %%
resid = np.array([-5.0, -3.0, -2.0, -1.0, 0.0, 1.0, 2.0, 3.0, 4.0, 6.0])
y_test = np.array([10.0, 20.0, 30.0, 40.0, 50.0])
pred_test = np.array([12.0, 18.0, 25.0, 41.0, 45.0])

# your solution here
lower = ____
upper = ____
coverage = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# `res` holds the RMSE of models A and B per month. Assign the number of months in which B has a **strictly lower** RMSE than A.
#
# Assign the result to `answer`.

# %%
res = pd.DataFrame({
    "month":  [1, 2, 3, 4, 5, 6],
    "rmse_a": [100, 110, 105, 120, 98, 130],
    "rmse_b": [102, 108, 106, 90, 99, 100],
})

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
