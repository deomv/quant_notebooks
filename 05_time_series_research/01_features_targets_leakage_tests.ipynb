# %% [markdown]
# # features targets leakage — exercises
#
# 12 tasks that test what the cheat sheet `01_features_targets_leakage.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.
# Convention used throughout: at time t you may use values up to and including t, never later.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12 = load_questions("05_time_series_research/01_features_targets_leakage")

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Task 1
#
# `y` is an hourly series. Build the target for a forecast **2 hours ahead**: at each timestamp the value that will be observed 2 hours later. The last two entries must be NaN.
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50, 60, 70, 80], index=pd.date_range('2023-01-01', periods=8, freq='h'))

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Build a DataFrame with two lag features of `y`: `lag1` (value 1 hour earlier) and `lag2` (value 2 hours earlier). Keep the same index as `y`.
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50, 60, 70, 80], index=pd.date_range('2023-01-01', periods=8, freq='h'))

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Build the **honest** rolling feature: the mean of the 3 values **before** t (not including t). At 03:00 it must equal the mean of 00:00, 01:00 and 02:00.
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50, 60, 70, 80], index=pd.date_range('2023-01-01', periods=8, freq='h'))

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Compute the difference between the **leaky** rolling feature `y.rolling(3).mean()` and the honest one from the previous task, at 03:00. Assign that single number.
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50, 60, 70, 80], index=pd.date_range('2023-01-01', periods=8, freq='h'))

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Build one frame with column `lag1 = y.shift(1)` and column `target = y.shift(-1)`, drop the rows with any NaN **once**, and assign the **index** of the resulting frame.
#
# Assign the result to `answer`.

# %%
y = pd.Series([10, 20, 30, 40, 50, 60, 70, 80], index=pd.date_range('2023-01-01', periods=8, freq='h'))

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Encode the hour of day cyclically. From `hours` build a DataFrame with columns `hour_sin` = sin(2π·hour/24) and `hour_cos` = cos(2π·hour/24).
#
# Assign the result to `answer`.

# %%
hours = pd.Series([0, 6, 12, 18])

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Forecasts for 15:00 and 16:00 were issued at two origins (00:00 and 12:00). Your decision is made at 06:00, so only forecasts with `origin_datetime <= decision_time` may be used. Assign a Series of the usable `temp_forecast_c` values indexed by `forecast_datetime` (one value per target hour, the latest usable origin).
#
# Assign the result to `answer`.

# %%
fc = pd.DataFrame({
    "origin_datetime":   pd.to_datetime(["2023-01-01 00:00", "2023-01-01 00:00", "2023-01-01 12:00", "2023-01-01 12:00"]),
    "forecast_datetime": pd.to_datetime(["2023-01-01 15:00", "2023-01-01 16:00", "2023-01-01 15:00", "2023-01-01 16:00"]),
    "temp_forecast_c":   [5.0, 6.0, 7.0, 8.0],
})
decision_time = pd.Timestamp("2023-01-01 06:00")

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Fit a `StandardScaler` on `train` **only** and transform `test`. Assign the transformed test array (shape (2, 1)).
#
# Assign the result to `answer`.

# %%
train = np.array([[1.0], [2.0], [3.0], [4.0]])
test = np.array([[5.0], [6.0]])

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# `df` has a `group`, a value `y` and a flag `is_train`. Build the group-mean feature using **train rows only**: every row (train or test) gets the mean of `y` over the train rows of its group. Assign the resulting Series (same index as `df`).
#
# Assign the result to `answer`.

# %%
df = pd.DataFrame({
    "group":    ["A", "A", "B", "B", "A", "B"],
    "y":        [10, 20, 100, 200, 30, 300],
    "is_train": [True, True, True, True, False, False],
})

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# `s` has gaps. Fill them using **only past** values (a gap takes the last observed value before it).
#
# Assign the result to `answer`.

# %%
s = pd.Series([1.0, np.nan, np.nan, 4.0, np.nan, 6.0], index=pd.date_range('2023-01-01', periods=6, freq='h'))

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Aggregate the half-hourly values `hh` into hourly **sums** where each hour is labelled by its **start** time (00:00 covers 00:00 and 00:30).
#
# Assign the result to `answer`.

# %%
hh = pd.Series([1, 2, 3, 4], index=pd.date_range('2023-01-01 00:00', periods=4, freq='30min'))

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data. Load `../data/weather_forecasts.csv` (parse both datetime columns). For every hour of 2023-03-01 (24 target hours, UTC), the decision is made at 2023-02-28 12:00 UTC. Pick, per target hour, the forecast with the **latest origin_datetime that is <= the decision time**. Assign a Series of `horizon_h` indexed by `forecast_datetime` for those 24 hours (sorted by time).
#
# Assign the result to `answer`.

# %%
fc = pd.read_csv("../data/weather_forecasts.csv", parse_dates=["origin_datetime", "forecast_datetime"])
decision_time = pd.Timestamp("2023-02-28 12:00", tz="UTC")
targets = pd.date_range("2023-03-01 00:00", periods=24, freq="h", tz="UTC")

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
