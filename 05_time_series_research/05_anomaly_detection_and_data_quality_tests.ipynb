# %% [markdown]
# # anomaly detection and data quality — exercises
#
# 13 tasks that test what the cheat sheet `05_anomaly_detection_and_data_quality.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12, q13 = load_questions("05_time_series_research/05_anomaly_detection_and_data_quality")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# `kwh` contains a stuck stretch. Find the **length** of the longest run of identical consecutive values and the **position** (0-based) where that run starts.
#
# Assign the result to `run_len`, `run_start`.

# %%
kwh = pd.Series([0.5, 0.4, 0.3, 0.3, 0.3, 0.3, 0.6, 0.5])

# your solution here
run_len = ____
run_start = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# For each day, divide the daily total by the **median of the previous 3 days** (the current day excluded). The first three days have no full window and stay NaN.
#
# Assign the result to `answer`.

# %%
daily = pd.Series([10.0, 11.0, 9.0, 10.0, 10500.0, 9800.0], index=["d1", "d2", "d3", "d4", "d5", "d6"])

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Compute the robust z-score of `v`: (v − median) / (1.4826 × MAD), where MAD is the median of |v − median|.
#
# Assign the result to `answer`.

# %%
v = pd.Series([1.0, 1.1, 0.9, 1.0, 50.0, 1.0, 1.1])

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Using the same `v`: does the spike exceed 3 under the **plain** z-score ((v − mean) / std) and under the **robust** z-score? Assign two booleans.
#
# Assign the result to `spike_plain`, `spike_robust`.

# %%
v = pd.Series([1.0, 1.1, 0.9, 1.0, 50.0, 1.0, 1.1])

# your solution here
spike_plain = ____
spike_robust = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Build the CUSUM of `x`: cumulative sum of (log(x) − mean of log(x)). Assign the **position** (index label) where |CUSUM| is largest, i.e. the last point before the level shift.
#
# Assign the result to `answer`.

# %%
x = pd.Series([10.0, 10.0, 10.0, 10.0, 14.0, 14.0, 14.0, 14.0])

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# For each settlement date in `dates`, compute the number of half-hour periods in that local (Europe/London) day: 48 normally, 46 on the spring clock change, 50 on the autumn one. Return a Series indexed by the date strings.
#
# Assign the result to `answer`.

# %%
dates = ["2023-03-25", "2023-03-26", "2023-10-29", "2023-12-01"]

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# `toy` has the readings of one meter for days d1..d3 (4 periods expected per day). Return a Series indexed by ['d1', 'd2', 'd3'] with the number of **missing** periods per day. A day with no rows at all must show 4, not be absent.
#
# Assign the result to `answer`.

# %%
toy = pd.DataFrame({"date": ["d1", "d1", "d1", "d1", "d2", "d2", "d2"], "period": [1, 2, 3, 4, 1, 2, 4], "kwh": [0.1, 0.2, 0.1, 0.3, 0.2, 0.2, 0.1]})

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Count the rows of `toy` that break a physical rule: negative kWh on a meter **without** solar, or kWh above 11.5 (the half-hourly maximum of a 100 A supply).
#
# Assign the result to `answer`.

# %%
toy = pd.DataFrame({"kwh": [0.4, -0.3, -0.2, 15.0, -0.1, 3.0], "has_solar": [False, True, True, False, False, False]})

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# Compute the two-sample Kolmogorov–Smirnov statistic between `history` and `new_month` (use scipy.stats).
#
# Assign the result to `answer`.

# %%
history = pd.Series([1.0, 1.2, 0.9, 1.1, 1.0, 1.3])
new_month = pd.Series([1.0, 1200.0, 1100.0, 900.0, 1300.0, 1000.0])

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Fit `IsolationForest(n_estimators=100, random_state=0)` on `points` and assign the **row position** of the most anomalous point (the lowest `score_samples`).
#
# Assign the result to `answer`.

# %%
points = pd.DataFrame({"total": [10, 11, 9, 10, 12, 10, 11, 60], "peak": [1, 1.2, 0.9, 1.1, 1.3, 1.0, 1.1, 9]})

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Combine the two detection tables into one issues table with columns ['meter_id', 'date', 'issue_type'], where issue_type is 'stuck_value' for rows from `stuck` and 'level_shift' for rows from `shifts`. Sort by date then meter_id and reset the index.
#
# Assign the result to `answer`.

# %%
stuck = pd.DataFrame({"meter_id": ["m1", "m4"], "date": ["2023-06-05", "2023-02-01"], "run_length": [336, 40]})
shifts = pd.DataFrame({"meter_id": ["m2"], "date": ["2023-09-01"], "ratio": [1020.5]})

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: `m7` holds meter M100007 from the half-hourly panel with a `month` column. Compute the ratio of the mean kWh in September to the mean kWh in August.
#
# Assign the result to `answer`.

# %%
panel = pd.read_csv("../data/meter_halfhourly_2023.csv.gz")
m7 = panel[panel["meter_id"] == "M100007"].copy()
m7["month"] = m7["settlement_date"].str[:7]

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ## Task 13
#
# Real data: `m3` holds meter M100003, deduplicated and sorted by date and period. What is the length of its longest run of identical consecutive kWh readings?
#
# Assign the result to `answer`.

# %%
panel = pd.read_csv("../data/meter_halfhourly_2023.csv.gz")
m3 = panel[panel["meter_id"] == "M100003"].drop_duplicates().sort_values(["settlement_date", "settlement_period"]).reset_index(drop=True)

# your solution here
answer = ____

q13.check()

# %%
# q13.hint()
# q13.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
