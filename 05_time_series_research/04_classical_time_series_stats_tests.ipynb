# %% [markdown]
# # classical time series stats — exercises
#
# 11 tasks that test what the cheat sheet `04_classical_time_series_stats.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11 = load_questions("05_time_series_research/04_classical_time_series_stats")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Compute the lag-1 autocorrelation of `x` with the **standard estimator**: centre x with its overall mean, numerator = Σ xc[t]·xc[t−1] over t=1..n−1, denominator = Σ xc[t]² over all t.
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 3.0, 5.0, 7.0, 5.0, 3.0])

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# Estimate the partial autocorrelation at lag 2 of `x`: regress x[t] on an intercept, x[t−1] and x[t−2] with `np.linalg.lstsq` and assign the coefficient on x[t−2].
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 3.0, 5.0, 7.0, 5.0, 3.0, 1.0, 3.0, 5.0, 7.0])

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Assign the first difference of `x` (x[t] − x[t−1]) as a Series with the same index; the first value is NaN.
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 3.0, 5.0, 7.0, 5.0, 3.0])

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Assign the seasonal difference of `x` with period 4 (x[t] − x[t−4]); the first four values are NaN.
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 3.0, 5.0, 7.0, 2.0, 4.0, 6.0, 8.0])

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Assign the centred 3-point moving average of `x` (each value averaged with its neighbours on both sides; NaN at the ends).
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 3.0, 5.0, 7.0, 2.0, 4.0, 6.0, 8.0, 3.0, 5.0, 7.0, 9.0])

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# `x` has period 4. Assign the seasonal means by position: a Series indexed 0,1,2,3 with the mean of the values at positions t where t mod 4 equals that index.
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 3.0, 5.0, 7.0, 2.0, 4.0, 6.0, 8.0, 3.0, 5.0, 7.0, 9.0])

# your solution here
answer = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Fit an AR(1) by OLS: regress x[t] on an intercept and x[t−1] with `np.linalg.lstsq`. Assign the slope coefficient φ.
#
# Assign the result to `answer`.

# %%
x = pd.Series([8.0, 4.0, 2.0, 1.0, 0.5, 0.25, 0.125, 0.0625])

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# Simple exponential smoothing with α = 0.5: start with level = x[0], then for each later value update level = α·x[t] + (1−α)·level. Assign the level after processing **all** values of `x`.
#
# Assign the result to `answer`.

# %%
x = pd.Series([10.0, 20.0, 10.0, 20.0, 10.0, 20.0])
alpha = 0.5

# your solution here
answer = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# `y` is `x` moved one step later (y[t+1] = x[t]). Assign `ccf_plus1` = corr(x[t], y[t+1]) and `ccf_minus1` = corr(x[t+1], y[t]) using `np.corrcoef` on the aligned slices.
#
# Assign the result to `ccf_plus1`, `ccf_minus1`.

# %%
x = pd.Series([1.0, 5.0, 2.0, 8.0, 3.0, 6.0, 4.0])
y = x.shift(1).fillna(0.0)

# your solution here
ccf_plus1 = ____
ccf_minus1 = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Variance ratio at k = 2: var(x[t] − x[t−2]) / (2 · var(x[t] − x[t−1])), both variances with ddof=1 over the available differences.
#
# Assign the result to `answer`.

# %%
x = pd.Series([1.0, 2.0, 4.0, 7.0, 11.0, 16.0, 22.0, 29.0])

# your solution here
answer = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Real data: load `../data/hourly_power_clean.csv` and assign the lag-24 autocorrelation of `consumption_mwh` using pandas `Series.autocorr`.
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])

# your solution here
answer = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
