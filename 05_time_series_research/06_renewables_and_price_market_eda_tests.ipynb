# %% [markdown]
# # renewables and price market eda — exercises
#
# 13 tasks that test what the cheat sheet `06_renewables_and_price_market_eda.ipynb` covers. Try each one
# **before** looking at the cheat sheet.
#
# How it works:
# 1. Read the task. Write your code in the cell below it, assigning the result to the
#    variable the task names (usually `answer`).
# 2. Run the cell: the last line `qN.check()` tells you ✅ or ❌ with a short reason.
# 3. Stuck? Uncomment `qN.hint()` for a nudge, or `qN.solution()` to see the reference code.

# %%
import sys; sys.path.append("..")
from quantlearn import load_questions
q1, q2, q3, q4, q5, q6, q7, q8, q9, q10, q11, q12, q13 = load_questions("05_time_series_research/06_renewables_and_price_market_eda")

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1
#
# Turbine power curve: output fraction is 0 below cut-in (3 m/s), ((v − 3) / (12 − 3))³ between cut-in and rated (12 m/s), 1 from rated up to cut-out (25 m/s), and 0 at or above cut-out. Compute it for `speeds` as a NumPy array.
#
# Assign the result to `answer`.

# %%
speeds = np.array([2.0, 5.0, 8.0, 12.0, 26.0])

# your solution here
answer = ____

q1.check()

# %%
# q1.hint()
# q1.solution()

# %% [markdown]
# ## Task 2
#
# `mw` is hourly output of a 100 MW wind farm. Compute its capacity factor (average output divided by capacity).
#
# Assign the result to `answer`.

# %%
mw = pd.Series([0, 20, 80, 100], index=["h1", "h2", "h3", "h4"])

# your solution here
answer = ____

q2.check()

# %%
# q2.hint()
# q2.solution()

# %% [markdown]
# ## Task 3
#
# Build the duration curve of `mw`: the values sorted from largest to smallest, as a NumPy array.
#
# Assign the result to `answer`.

# %%
mw = pd.Series([30, 0, 100, 60, 0, 10])

# your solution here
answer = ____

q3.check()

# %%
# q3.hint()
# q3.solution()

# %% [markdown]
# ## Task 4
#
# Add a `net_load` Series = demand − wind − solar for the three periods in `toy` (keep the index).
#
# Assign the result to `answer`.

# %%
toy = pd.DataFrame({"demand": [30000, 32000, 35000], "wind": [2000, 2000, 8000], "solar": [0, 5000, 0]}, index=["night", "noon", "evening"])

# your solution here
answer = ____

q4.check()

# %%
# q4.hint()
# q4.solution()

# %% [markdown]
# ## Task 5
#
# Largest absolute hour-to-hour ramp in `mw` (as a number).
#
# Assign the result to `answer`.

# %%
mw = pd.Series([100, 300, 900, 400, 350])

# your solution here
answer = ____

q5.check()

# %%
# q5.hint()
# q5.solution()

# %% [markdown]
# ## Task 6
#
# Count the spikes in `px` under two definitions: `n_fixed` = prices above mean + 2 × std (pandas std), `n_quantile` = prices above the 75th percentile.
#
# Assign the result to `n_fixed`, `n_quantile`.

# %%
px = pd.Series([80, 90, 85, 400, 95, 88, 92, 250])

# your solution here
n_fixed = ____
n_quantile = ____

q6.check()

# %%
# q6.hint()
# q6.solution()

# %% [markdown]
# ## Task 7
#
# Average price per hour of day from `toy`, as a Series indexed by hour.
#
# Assign the result to `answer`.

# %%
toy = pd.DataFrame({"hour": [1, 2, 1, 2, 3, 3], "price": [10, 20, 30, 40, 50, 70]})

# your solution here
answer = ____

q7.check()

# %%
# q7.hint()
# q7.solution()

# %% [markdown]
# ## Task 8
#
# On the toy `day`, the peak block is hours 7–18 inclusive. Compute `peak` = mean price in the peak block and `offpeak` = mean price outside it.
#
# Assign the result to `peak`, `offpeak`.

# %%
day = pd.DataFrame({"hour": [2, 4, 6, 10, 14, 18], "price": [50, 45, 60, 100, 90, 140]})

# your solution here
peak = ____
offpeak = ____

q8.check()

# %%
# q8.hint()
# q8.solution()

# %% [markdown]
# ## Task 9
#
# A 4-hour battery earns the average of the 4 highest prices minus the average of the 4 lowest. Compute that spread for `px`.
#
# Assign the result to `answer`.

# %%
px = pd.Series([80, 90, 85, 400, 95, 88, 92, 250])

# your solution here
answer = ____

q9.check()

# %%
# q9.hint()
# q9.solution()

# %% [markdown]
# ## Task 10
#
# Compute `time_weighted` = the plain mean of `price`, and `load_weighted` = total cost (price × volume) divided by total volume.
#
# Assign the result to `time_weighted`, `load_weighted`.

# %%
toy = pd.DataFrame({"price": [50, 100, 300], "volume_mwh": [10, 10, 1]})

# your solution here
time_weighted = ____
load_weighted = ____

q10.check()

# %%
# q10.hint()
# q10.solution()

# %% [markdown]
# ## Task 11
#
# Degree-day features from `t`: `hdd` = heating degrees below 15 (0 when warmer), `cdd` = cooling degrees above 22 (0 when colder). Both as Series.
#
# Assign the result to `hdd`, `cdd`.

# %%
t = pd.Series([-5, 5, 15, 20, 26], name="temp_c")

# your solution here
hdd = ____
cdd = ____

q11.check()

# %%
# q11.hint()
# q11.solution()

# %% [markdown]
# ## Task 12
#
# Real data: apply `power_curve` to the `wind_ms` column of `df` for a 10,000 MW fleet and compute the fleet's overall capacity factor (a number between 0 and 1).
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])

def power_curve(v, cut_in=3.0, rated=12.0, cut_out=25.0):
    v = np.asarray(v, dtype=float)
    cubic = ((v - cut_in) / (rated - cut_in)) ** 3
    out = np.where(v < cut_in, 0.0, np.where(v < rated, cubic, 1.0))
    return np.where(v >= cut_out, 0.0, out)

# your solution here
answer = ____

q12.check()

# %%
# q12.hint()
# q12.solution()

# %% [markdown]
# ## Task 13
#
# Real data: how many hours in 2023 had a negative day-ahead price?
#
# Assign the result to `answer`.

# %%
df = pd.read_csv("../data/hourly_power_clean.csv", parse_dates=["time"])

# your solution here
answer = ____

q13.check()

# %%
# q13.hint()
# q13.solution()

# %% [markdown]
# ---
# Done? Re-open the cheat sheet for anything you had to look up, then try the next `_tests` notebook.
